# %% [markdown]
# # 2. Identification based on user movements (normalized height)

# %%
# import numpy for math calculations
import numpy as np

# import pandas for data (csv) manipulation
import pandas as pd

# import matplotlib for plotting
import matplotlib.pyplot as plt

import sys  
sys.path.insert(1, '../src/')

from train_model import ClassifierEvaluator
from visualize import VisualizationUtils
import seaborn as sns
# import shap for ai explainability
import shap

from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn import tree

# import warnings to hide the unnessairy warniings
import warnings
warnings.filterwarnings('ignore')

# %%
mov_slow = pd.read_csv('../data/processed/movement_slow_stat_cleaned.csv').drop(columns=['Unnamed: 0']).fillna(0)
mov_fast = pd.read_csv('../data/processed/movement_fast_stat_cleaned.csv').drop(columns=['Unnamed: 0']).fillna(0)
traffic_slow = pd.read_csv('../data/processed/traffic_slow_stat_cleaned.csv', index_col=0).fillna(0)
traffic_fast = pd.read_csv('../data/processed/traffic_fast_stat_cleaned.csv', index_col=0).fillna(0)

# %%
for col in mov_fast.columns.values:
    if "PosY" in col and "Accel" not in col and "Velocity" not in col:
        print(col)
        for id in range(60):
            #print(id, col, mov_fast.loc[mov_fast['ID'] == id][col])
            print(id, col, np.mean(mov_fast.loc[mov_fast['ID'] == id,col]), np.max(mov_fast.loc[mov_fast['ID'] == id,col]), np.min(mov_fast.loc[mov_fast['ID'] == id,col]))
            mov_fast.loc[mov_fast['ID'] == id,col] = mov_fast.loc[mov_fast['ID'] == id,col] / np.mean(mov_fast.loc[mov_fast['ID'] == id,col])
            print(id, col, np.mean(mov_fast.loc[mov_fast['ID'] == id,col]), np.max(mov_fast.loc[mov_fast['ID'] == id,col]), np.min(mov_fast.loc[mov_fast['ID'] == id,col]))
            mov_slow.loc[mov_slow['ID'] == id,col] = mov_slow.loc[mov_slow['ID'] == id,col] / np.mean(mov_fast.loc[mov_fast['ID'] == id,col])
# Out:
# HeadPosY_25%
# 0 HeadPosY_25% 0.7134620286105323 0.7278551096508605 0.6570334403533158
# 0 HeadPosY_25% 0.9999999999999999 1.0201735768171976 0.9209087716032888
# 1 HeadPosY_25% 0.7788999002622312 0.8124401626932196 0.2526097097609505
# 1 HeadPosY_25% 0.9999999999999998 1.0430610691048958 0.3243160124630966
# 2 HeadPosY_25% 0.9066900340050817 0.9214591842635648 0.7479711538667484
# 2 HeadPosY_25% 1.0000000000000002 1.0162890841462588 0.824946923220021
# 3 HeadPosY_25% 0.8121922818530807 0.8303501245472713 0.7458421772961998
# 3 HeadPosY_25% 1.0 1.0223565811937563 0.918307393409972
# 4 HeadPosY_25% 0.8161531278178419 0.8245928921311398 0.7965606533430714
# 4 HeadPosY_25% 1.0 1.0103409078831365 0.9759941194771192
# 5 HeadPosY_25% 0.8564253755159127 0.9103195392500604 0.7888929107650393
# 5 HeadPosY_25% 0.9999999999999999 1.0629291999920971 0.9211461188779096
# 6 HeadPosY_25% 0.8777812166008767 0.8872263547594619 0.8320635865758819
# 6 HeadPosY_25% 1.0 1.0107602418233106 0.9479168280656176
# 7 HeadPosY_25% 0.8579400402520787 0.8828977213096847 0.5610110282699816
# 7 HeadPosY_25% 1.0000000000000002 1.0290902392785781 0.6539047042321817
# 8 HeadPosY_25% 0.8642056354338236 0.8860097967191485 0.3410453403471044
# 8 HeadPosY_25% 1.0 1.0252302928739634 0.3946344786052022
# 9 HeadPosY_25% 0.7849948917413271 0.804768136460116 0.7289431580390282
# 9 HeadPosY_25% 1.0000000000000002 1.0251890106888806 0.9285960529272219
# 10 HeadPosY_25% 0.8368440028472027 0.8617450325664875 0.7500701448517963
# 10 HeadPosY_25% 1.0 1.0297558799902535 0.8963082035598333
# 11 HeadPosY_25% 0.9593385108444299 0.9791043305610948 0.5813948009278398
# 11 HeadPosY_25% 0.9999999999999999 1.0206035924683838 0.6060371749447272
# 12 HeadPosY_25% 0.9685284502521287 0.9812889946475732 0.8704344268790789
# 12 HeadPosY_25% 1.0 1.013175187979375 0.8987184905642019
# 13 HeadPosY_25% 0.8132475602799512 0.8358203520736103 0.7349359914840936
# 13 HeadPosY_25% 1.0 1.0277563596820243 0.9037051291381684
# 14 HeadPosY_25% 0.9001959415223967 0.9371352199978152 0.6479735098770376
# 14 HeadPosY_25% 1.0000000000000002 1.0410347089689689 0.7198138538385269
# 15 HeadPosY_25% 0.8574999946454313 0.8865131261900527 0.2114065167244602
# 15 HeadPosY_25% 0.9999999999999999 1.0338345559484443 0.24653821346305074
# 16 HeadPosY_25% 0.8395020108190848 0.8540515880580264 0.7600938977191678
# 16 HeadPosY_25% 1.0000000000000002 1.0173311999869372 0.9054104551549077
# 17 HeadPosY_25% 0.9169263811039406 0.939561910595835 0.3274243881334187
# 17 HeadPosY_25% 1.0000000000000002 1.0246863106552155 0.35708906939640406
# 18 HeadPosY_25% 0.6696012202705414 0.6858581553296166 0.3672206146616661
# 18 HeadPosY_25% 0.9999999999999999 1.024278532605581 0.5484168838779844
# 19 HeadPosY_25% 0.8591254347017468 0.880344662887055 0.7477933821812799
# 19 HeadPosY_25% 1.0000000000000002 1.024698638089646 0.8704123425712371
# 20 HeadPosY_25% 0.7791737257732532 0.7906663439646513 0.669818008914286
# 20 HeadPosY_25% 1.0000000000000002 1.0147497506797896 0.8596516883953673
# 21 HeadPosY_25% 0.7444650892820807 0.783893885296568 0.5962141056477848
# 21 HeadPosY_25% 1.0000000000000002 1.0529625855962033 0.8008624101134674
# 22 HeadPosY_25% 0.7666712715958686 0.7763118158199667 0.7480739615884648
# 22 HeadPosY_25% 1.0 1.0125745473728667 0.9757427848200281
# 23 HeadPosY_25% 0.9007675738734165 0.9332306684001191 0.1781987658789738
# 23 HeadPosY_25% 1.0 1.0360393684989204 0.19782990756727192
# 24 HeadPosY_25% 0.9571193633346256 0.9799931889884363 0.3596599634604223
# 24 HeadPosY_25% 1.0000000000000002 1.0238986134123522 0.3757733645753011
# 25 HeadPosY_25% 0.6516043002185378 0.6837291787590678 0.3205544763124583
# 25 HeadPosY_25% 1.0 1.049301207081899 0.4919465328957305
# 26 HeadPosY_25% 0.8547980863484911 0.8828527429314337 0.7880618816811633
# 26 HeadPosY_25% 1.0 1.0328202145407062 0.9219275221445451
# 27 HeadPosY_25% 0.8958106924314241 0.9473067589651548 0.5163432150116407
# 27 HeadPosY_25% 1.0 1.0574854341088062 0.5763976913583979
# 28 HeadPosY_25% 0.8066681837945044 0.833717077433491 0.1720078133868504
# 28 HeadPosY_25% 1.0 1.033531623265158 0.21323242547851462
# 29 HeadPosY_25% 0.9279467441722657 0.94022159347685 0.7889528819360407
# 29 HeadPosY_25% 1.0 1.0132279674255804 0.8502135353034636
# 30 HeadPosY_25% 0.8510029464407467 0.9441796907629404 0.3016142954137045
# 30 HeadPosY_25% 1.0 1.1094905073030572 0.35442215173893665
# 31 HeadPosY_25% 0.9284136054596612 1.0346847551141487 0.3264817698349292
# 31 HeadPosY_25% 0.9999999999999999 1.1144653083814646 0.35165552068066347
# 32 HeadPosY_25% 0.9033280430193199 0.9657586031857543 0.5745259600206472
# 32 HeadPosY_25% 1.0000000000000002 1.0691117259658673 0.6360103225626966
# 33 HeadPosY_25% 0.759901668697833 0.7966741702024669 0.6704776917953013
# 33 HeadPosY_25% 1.0000000000000002 1.0483911314047345 0.8823216468839071
# 34 HeadPosY_25% 0.7747359662105286 0.8238261178733366 0.6836906258634241
# 34 HeadPosY_25% 1.0 1.0633637184845348 0.8824821044614267
# 35 HeadPosY_25% 0.8976101845327211 0.9409583821491524 0.7942346286392326
# 35 HeadPosY_25% 0.9999999999999999 1.0482928985916058 0.8848324610450984
# 36 HeadPosY_25% 0.8941961471378402 0.9277882846317448 0.7804969468248477
# 36 HeadPosY_25% 0.9999999999999998 1.0375668555511304 0.8728475841940014
# 37 HeadPosY_25% 0.9978332201734452 1.0314548791902178 0.9395747615610496
# 37 HeadPosY_25% 0.9999999999999999 1.033694667943535 0.9416150340211473
# 38 HeadPosY_25% 0.6978009856690319 0.7171673902474025 0.6236937529316264
# 38 HeadPosY_25% 1.0 1.0277534783929871 0.8937988993146039
# 39 HeadPosY_25% 0.8496494899237725 0.8851402147396288 0.7977579349355632
# 39 HeadPosY_25% 0.9999999999999998 1.0417710187986347 0.9389259269809427
# 40 HeadPosY_25% 0.7627033897276523 0.8468207782972899 0.2141791124695056
# 40 HeadPosY_25% 1.0 1.1102884682336005 0.2808157343393808
# 41 HeadPosY_25% 0.9642939501225481 1.0113559695946164 0.8544199823941776
# 41 HeadPosY_25% 1.0000000000000002 1.04880464039631 0.8860575992264526
# 42 HeadPosY_25% 0.8786486246254479 0.954222720078134 0.2733530952620632
# 42 HeadPosY_25% 1.0 1.0860117381790724 0.31110626887806114
# 43 HeadPosY_25% 0.8476593287655293 0.9281652462780392 0.1485993518829876
# 43 HeadPosY_25% 0.9999999999999999 1.0949743780083834 0.17530551111777076
# 44 HeadPosY_25% 0.9099256928633593 0.9749577524518572 0.8519076186947274
# 44 HeadPosY_25% 1.0000000000000002 1.0714696376842099 0.936238668032265
# 45 HeadPosY_25% 0.869640844079953 0.9135879680696352 0.7746668922725004
# 45 HeadPosY_25% 0.9999999999999999 1.0505347975418249 0.890789453538223
# 46 HeadPosY_25% 0.8820296743065654 0.9344814956810048 0.7798629658742617
# 46 HeadPosY_25% 1.0 1.0594671844977053 0.8841686267385219
# 47 HeadPosY_25% 0.7059160132307826 0.7293436797882162 0.6787622807036331
# 47 HeadPosY_25% 1.0000000000000002 1.0331876117248164 0.9615340465179784
# 48 HeadPosY_25% 0.7783472159454777 0.8326932838713961 0.0563035055291276
# 48 HeadPosY_25% 0.9999999999999998 1.0698223964993603 0.07233726076958383
# 49 HeadPosY_25% 0.8138757582961905 0.8462639031379915 0.7502843276053726
# 49 HeadPosY_25% 0.9999999999999999 1.0397949496734047 0.9218659235852613
# 50 HeadPosY_25% 0.8890999183963709 0.9418708006793876 0.8358417703489678
# 50 HeadPosY_25% 1.0000000000000002 1.05935315164374 0.9400988044814328
# 51 HeadPosY_25% 0.7723015293362546 0.8208318429783397 0.6289433722217819
# 51 HeadPosY_25% 1.0000000000000004 1.0628385569607688 0.8143754069247018
# 52 HeadPosY_25% 0.7574847234151011 0.9200113088493888 0.2767052695382861
# 52 HeadPosY_25% 1.0 1.214560875500618 0.3652948514799972
# 53 HeadPosY_25% 0.8701806917103421 0.9089423441445648 0.8162097791561629
# 53 HeadPosY_25% 1.0 1.0445443719947827 0.9379773499132701
# 54 HeadPosY_25% 0.97464111894782 1.033209035942008 0.8734693964972553
# 54 HeadPosY_25% 1.0 1.0600917772250522 0.8961959222900576
# 55 HeadPosY_25% 0.8087567904857166 0.8503719283515851 0.6243491521575699
# 55 HeadPosY_25% 0.9999999999999999 1.0514556889727946 0.7719862874753773
# 56 HeadPosY_25% 0.7762980010323608 0.8094051930750432 0.6736026181699797
# 56 HeadPosY_25% 1.0 1.042647529684032 0.8677113908243851
# 57 HeadPosY_25% 0.9058640739130405 0.9340274282434228 0.77765474168489
# 57 HeadPosY_25% 0.9999999999999999 1.031090044457471 0.8584673618037113
# 58 HeadPosY_25% 0.871062375015439 0.894380058728911 0.7366580208228473
# 58 HeadPosY_25% 0.9999999999999999 1.0267692468212264 0.8457006546859408
# 59 HeadPosY_25% 0.7671691751036822 0.7962136772822779 0.6654593898790082
# 59 HeadPosY_25% 1.0 1.0378593185455742 0.8674219604679398
# HeadPosY_50%
# 0 HeadPosY_50% 0.6994218181177297 0.7108612641289453 0.6826100944274625
# 0 HeadPosY_50% 1.0 1.016355575011945 0.9759633982601362
# 1 HeadPosY_50% 0.780689522706831 0.8002657984752881 0.7368182865049473
# 1 HeadPosY_50% 0.9999999999999998 1.0250756225094217 0.9438045023970963
# 2 HeadPosY_50% 0.9033693496540408 0.9131002085344072 0.8552357191569366
# 2 HeadPosY_50% 1.0 1.0107717390279989 0.9467176625866953
# 3 HeadPosY_50% 0.8009119982411536 0.820223087904377 0.7751287545378862
# 3 HeadPosY_50% 1.0000000000000002 1.0241113751643522 0.9678076445853118
# 4 HeadPosY_50% 0.8044947364553451 0.8123235142035501 0.7939479318172247
# 4 HeadPosY_50% 1.0000000000000002 1.0097312976623056 0.9868901508484812
# 5 HeadPosY_50% 0.8489400322435235 0.900518244296221 0.8031962132230708
# 5 HeadPosY_50% 1.0 1.0607560134917773 0.9461165485392837
# 6 HeadPosY_50% 0.8686580492757751 0.879225689431598 0.8584439408074145
# 6 HeadPosY_50% 1.0000000000000002 1.012165477732732 0.9882415082933078
# 7 HeadPosY_50% 0.8621035986747714 0.8789209979899326 0.826110801938913
# 7 HeadPosY_50% 1.0000000000000002 1.0195073995062924 0.9582500330688949
# 8 HeadPosY_50% 0.862759805463476 0.8810359150556106 0.4723013075743605
# 8 HeadPosY_50% 1.0000000000000002 1.0211833113647624 0.5474308197756611
# 9 HeadPosY_50% 0.7755680927122288 0.7969769232078989 0.7414155426688998
# 9 HeadPosY_50% 1.0 1.0276040630047087 0.9559644725405159
# 10 HeadPosY_50% 0.8365808362824178 0.8553342957998284 0.8151867176039065
# 10 HeadPosY_50% 1.0000000000000002 1.0224167930988557 0.97442671676107
# 11 HeadPosY_50% 0.961352803116456 0.9744955340300014 0.8137080679605297
# 11 HeadPosY_50% 0.9999999999999999 1.0136710798272395 0.846419821446091
# 12 HeadPosY_50% 0.968951494018638 0.9793705970966492 0.9576478896084984
# 12 HeadPosY_50% 1.0000000000000004 1.0107529666266357 0.988334189606067
# 13 HeadPosY_50% 0.804688827890857 0.8317475936097243 0.7921242639237267
# 13 HeadPosY_50% 1.0000000000000002 1.0336263718110639 0.9843858103509864
# 14 HeadPosY_50% 0.9016367904759427 0.9326452683659489 0.8815915288610006
# 14 HeadPosY_50% 1.0000000000000002 1.0343913183418767 0.9777679196027915
# 15 HeadPosY_50% 0.8582399170283384 0.8772541565737628 0.4929127874517309
# 15 HeadPosY_50% 1.0000000000000002 1.0221549233124245 0.574329832103877
# 16 HeadPosY_50% 0.8334481153788823 0.8441682506140877 0.8165847136303717
# 16 HeadPosY_50% 1.0000000000000002 1.0128623906364371 0.9797667048046002
# 17 HeadPosY_50% 0.9209487762904653 0.9323674614632538 0.7989529368222295
# 17 HeadPosY_50% 0.9999999999999999 1.0123988276728944 0.8675324376241327
# 18 HeadPosY_50% 0.6554596972382708 0.6655115276422348 0.6194448701163113
# 18 HeadPosY_50% 0.9999999999999999 1.015335543049125 0.9450540936785203
# 19 HeadPosY_50% 0.8543085012795548 0.8719579023965776 0.8282077959786107
# 19 HeadPosY_50% 0.9999999999999998 1.0206592830231562 0.9694481498640698
# 20 HeadPosY_50% 0.7685907333773642 0.7766432502332234 0.7564305576839148
# 20 HeadPosY_50% 1.0 1.0104769892560046 0.9841786074624985
# 21 HeadPosY_50% 0.7430448950890611 0.7678430444768851 0.7110628981712241
# 21 HeadPosY_50% 1.0 1.0333736891966019 0.956958190374212
# 22 HeadPosY_50% 0.752992921300889 0.7619105228773986 0.7388749537361892
# 22 HeadPosY_50% 1.0000000000000002 1.0118428757087161 0.9812508628363872
# 23 HeadPosY_50% 0.9156360179935231 0.9282272424617992 0.8452615551988873
# 23 HeadPosY_50% 1.0000000000000002 1.0137513424776232 0.9231414433118843
# 24 HeadPosY_50% 0.9622679229513011 0.976036914264309 0.8246231907825461
# 24 HeadPosY_50% 1.0 1.014308895666789 0.8569579959117882
# 25 HeadPosY_50% 0.6520881520135473 0.6757634985029792 0.6151209400985587
# 25 HeadPosY_50% 1.0000000000000002 1.0363069723262508 0.9433094869139401
# 26 HeadPosY_50% 0.8465275182672973 0.8710662318540563 0.8312188643433049
# 26 HeadPosY_50% 1.0 1.0289874966344694 0.981915940600104
# 27 HeadPosY_50% 0.9052096710258453 0.9424312405512048 0.7882304865295018
# 27 HeadPosY_50% 1.0000000000000002 1.0411192795622448 0.8707711724248651
# 28 HeadPosY_50% 0.8119047875090849 0.8245470179221299 0.7860125120644368
# 28 HeadPosY_50% 0.9999999999999998 1.0155710750909983 0.9681092218656755
# 29 HeadPosY_50% 0.9258507985753585 0.9337564959767288 0.9152778561910164
# 29 HeadPosY_50% 1.0 1.0085388460144282 0.9885802956582086
# 30 HeadPosY_50% 0.8605510165492259 0.9387211741732782 0.4692364701317251
# 30 HeadPosY_50% 1.0000000000000002 1.090837331106192 0.5452744359228625
# 31 HeadPosY_50% 0.9431831861703543 1.0379430460003425 0.3355306963185207
# 31 HeadPosY_50% 0.9999999999999998 1.1004681394022147 0.3557428728992614
# 32 HeadPosY_50% 0.9165245520064977 0.9656281169262368 0.8290188129042202
# 32 HeadPosY_50% 0.9999999999999999 1.0535758314518027 0.9045243917244705
# 33 HeadPosY_50% 0.7561322139806175 0.7963182520031222 0.7060175663577632
# 33 HeadPosY_50% 1.0000000000000002 1.0531468403005178 0.9337223746108788
# 34 HeadPosY_50% 0.7680391522528198 0.8109658449855406 0.6929964879830592
# 34 HeadPosY_50% 1.0 1.055891281853025 0.9022931786099124
# 35 HeadPosY_50% 0.903856482564331 0.9397024598457008 0.8670828393299297
# 35 HeadPosY_50% 1.0 1.0396589259167242 0.9593147319914431
# 36 HeadPosY_50% 0.8948275341889188 0.9227741618072864 0.7822710803910444
# 36 HeadPosY_50% 1.0000000000000002 1.0312313005027263 0.8742143603125749
# 37 HeadPosY_50% 1.002315356239558 1.0393410420268074 0.9750421863224012
# 37 HeadPosY_50% 0.9999999999999999 1.03694015616618 0.9727898313166836
# 38 HeadPosY_50% 0.6877496714858696 0.7046195703312981 0.6510386841631246
# 38 HeadPosY_50% 0.9999999999999999 1.0245291267227818 0.9466215850842478
# 39 HeadPosY_50% 0.8455807344198869 0.8798753991233847 0.8155720626624834
# 39 HeadPosY_50% 0.9999999999999999 1.0405575284624073 0.9645111690275311
# 40 HeadPosY_50% 0.7690367553468122 0.8465564938259655 0.1946413736924032
# 40 HeadPosY_50% 0.9999999999999999 1.1008010838756261 0.25309762158848426
# 41 HeadPosY_50% 0.966343096304302 1.0075904015026664 0.9041342147877508
# 41 HeadPosY_50% 0.9999999999999998 1.042683913566632 0.935624436336883
# 42 HeadPosY_50% 0.8823675510783837 0.9658969623159416 0.2966440030003144
# 42 HeadPosY_50% 1.0000000000000002 1.0946650986150528 0.3361909701209791
# 43 HeadPosY_50% 0.8626412147749061 0.922877219206673 0.1525545240854103
# 43 HeadPosY_50% 1.0000000000000002 1.0698274130659113 0.17684585604365916
# 44 HeadPosY_50% 0.9110248714844359 0.9730616919515755 0.8505354055935972
# 44 HeadPosY_50% 1.0 1.0680956386690694 0.9336028380956534
# 45 HeadPosY_50% 0.8656123297275192 0.910694042296549 0.7717278603581201
# 45 HeadPosY_50% 1.0 1.0520807190711121 0.8915398196800727
# 46 HeadPosY_50% 0.8828084276457897 0.9258793260583772 0.786975874710879
# 46 HeadPosY_50% 0.9999999999999999 1.0487884993661036 0.8914458109666329
# 47 HeadPosY_50% 0.6891529697408539 0.7109822445543126 0.6610845402250953
# 47 HeadPosY_50% 1.0000000000000002 1.031675514395109 0.9592711186802063
# 48 HeadPosY_50% 0.7845246768702455 0.8289874476087546 0.0225901819455981
# 48 HeadPosY_50% 0.9999999999999998 1.0566747892697108 0.028794737261444162
# 49 HeadPosY_50% 0.8098357981974813 0.8388361503849417 0.7405641989348346
# 49 HeadPosY_50% 0.9999999999999998 1.0358101633096597 0.9144621670012238
# 50 HeadPosY_50% 0.8899612085974365 0.9422609718043916 0.8340014141267498
# 50 HeadPosY_50% 1.0000000000000002 1.058766340264851 0.9371210858067865
# 51 HeadPosY_50% 0.7718553378804052 0.8096843486279475 0.693493851954013
# 51 HeadPosY_50% 0.9999999999999998 1.0490104931468436 0.8984764604445428
# 52 HeadPosY_50% 0.7614873527660755 0.9211118011476114 0.262803537646868
# 52 HeadPosY_50% 1.0000000000000002 1.2096219297690314 0.34511871627577734
# 53 HeadPosY_50% 0.8658188179226676 0.8996982658576211 0.8166743287602733
# 53 HeadPosY_50% 0.9999999999999999 1.0391299510170493 0.9432392919337269
# 54 HeadPosY_50% 0.9880367535545094 1.0334891740442322 0.9103131779944672
# 54 HeadPosY_50% 1.0000000000000002 1.0460027628792203 0.9213353397225074
# 55 HeadPosY_50% 0.806688216118237 0.8407001450868954 0.6846264348502487
# 55 HeadPosY_50% 0.9999999999999999 1.042162421973043 0.8486877844139753
# 56 HeadPosY_50% 0.7694222124243013 0.8002120293973474 0.6880228482735196
# 56 HeadPosY_50% 1.0000000000000002 1.0400168028370709 0.8942071559198843
# 57 HeadPosY_50% 0.9084860001750481 0.9311128496446311 0.7932937413689427
# 57 HeadPosY_50% 1.0000000000000002 1.0249061069353003 0.8732041453760322
# 58 HeadPosY_50% 0.8710212002512808 0.8868788215251957 0.8429226003084553
# 58 HeadPosY_50% 0.9999999999999999 1.018205781064043 0.9677406245281753
# 59 HeadPosY_50% 0.759640198240616 0.7968066544610859 0.6793929112639945
# 59 HeadPosY_50% 1.0 1.0489263947676153 0.8943614527476557
# HeadPosY_75%
# 0 HeadPosY_75% 0.633855580924512 0.6491516730927941 0.6131670957983281
# 0 HeadPosY_75% 0.9999999999999998 1.0241318253378346 0.9673608851151729
# 1 HeadPosY_75% 0.731391349851214 0.7501959079323838 0.6950032412674528
# 1 HeadPosY_75% 1.0000000000000002 1.0257106651384311 0.950248100977454
# 2 HeadPosY_75% 0.8705538879154964 0.8863890197834471 0.8378168696906346
# 2 HeadPosY_75% 1.0000000000000002 1.0181897204616102 0.9623951846298118
# 3 HeadPosY_75% 0.7504258773768213 0.7741057876800596 0.7187491050717375
# 3 HeadPosY_75% 0.9999999999999996 1.0315552954890275 0.9577882729526696
# 4 HeadPosY_75% 0.7546600921439836 0.7653452535608382 0.7448901223350662
# 4 HeadPosY_75% 0.9999999999999999 1.0141589061460745 0.9870538141467625
# 5 HeadPosY_75% 0.8077671095097139 0.8646998638407327 0.7618488501961683
# 5 HeadPosY_75% 0.9999999999999999 1.0704816445987446 0.9431540864031759
# 6 HeadPosY_75% 0.8291519247574691 0.8644343142180996 0.8170232928673892
# 6 HeadPosY_75% 0.9999999999999999 1.0425523820269136 0.9853722441835643
# 7 HeadPosY_75% 0.8244786419132766 0.8454709470488847 0.7907677247864539
# 7 HeadPosY_75% 0.9999999999999996 1.025461308599691 0.9591124434120045
# 8 HeadPosY_75% 0.8332015565026247 0.8463561124576616 0.8157710441567368
# 8 HeadPosY_75% 1.0000000000000002 1.0157879637314329 0.979080077071564
# 9 HeadPosY_75% 0.722877967799071 0.7452728262029787 0.7011134860156883
# 9 HeadPosY_75% 1.0 1.0309801368993066 0.9698919004964995
# 10 HeadPosY_75% 0.7966525994791408 0.8138705419555387 0.7812860412018466
# 10 HeadPosY_75% 1.0000000000000002 1.021612861726247 0.9807110925297413
# 11 HeadPosY_75% 0.9423193676794868 0.9600946606301858 0.9276403312601372
# 11 HeadPosY_75% 0.9999999999999999 1.0188633424721723 0.9844224400741147
# 12 HeadPosY_75% 0.9472132476284945 0.964286179183513 0.938215454467352
# 12 HeadPosY_75% 1.0000000000000002 1.0180243800408868 0.9905007735231006
# 13 HeadPosY_75% 0.754980530700053 0.7840821225225133 0.7412323064546783
# 13 HeadPosY_75% 1.0000000000000002 1.0385461487271412 0.9817899618780543
# 14 HeadPosY_75% 0.8689093026545418 0.902988474625692 0.8466164552249492
# 14 HeadPosY_75% 1.0 1.039220631965888 0.9743438729894048
# 15 HeadPosY_75% 0.8246572370516356 0.8417272180552918 0.7827804086860762
# 15 HeadPosY_75% 1.0 1.0206994860854988 0.9492191100932068
# 16 HeadPosY_75% 0.7899845703519921 0.8062997742828207 0.769940303403461
# 16 HeadPosY_75% 1.0000000000000002 1.0206525602437515 0.9746270146268806
# 17 HeadPosY_75% 0.8917896569289795 0.9035846595627804 0.8836189727395088
# 17 HeadPosY_75% 0.9999999999999998 1.0132262160052619 0.9908378796210671
# 18 HeadPosY_75% 0.5806506312878201 0.5907177389751345 0.5736158225920248
# 18 HeadPosY_75% 1.0000000000000002 1.0173376332425346 0.987884610268669
# 19 HeadPosY_75% 0.8144810023543665 0.834133019533518 0.782395101390491
# 19 HeadPosY_75% 1.0 1.0241282695634948 0.9606057098064572
# 20 HeadPosY_75% 0.7141783104969335 0.7246328516124331 0.6991921563931071
# 20 HeadPosY_75% 1.0000000000000002 1.0146385586930318 0.9790162290235349
# 21 HeadPosY_75% 0.6906205443420141 0.7146669304806709 0.6574826416459912
# 21 HeadPosY_75% 0.9999999999999998 1.034818521307626 0.9520172068909493
# 22 HeadPosY_75% 0.6953872034587405 0.709100802116066 0.6774144839095154
# 22 HeadPosY_75% 1.0 1.0197208096282422 0.974154371176473
# 23 HeadPosY_75% 0.8878015962482873 0.8998539477075519 0.8697921683688744
# 23 HeadPosY_75% 1.0 1.013575501001796 0.979714580424818
# 24 HeadPosY_75% 0.9421002458503533 0.9824112426420628 0.9304468262914954
# 24 HeadPosY_75% 0.9999999999999999 1.0427884367605957 0.987630382636893
# 25 HeadPosY_75% 0.5822380713113551 0.6087516824651339 0.5335230364297635
# 25 HeadPosY_75% 1.0000000000000004 1.0455374055050422 0.9163314161647446
# 26 HeadPosY_75% 0.8026455598107134 0.8295535902569325 0.7832932839376324
# 26 HeadPosY_75% 1.0000000000000002 1.0335241752942168 0.9758893877421501
# 27 HeadPosY_75% 0.8819366811677589 0.9441382524231404 0.81231369220716
# 27 HeadPosY_75% 1.0 1.0705283866558553 0.9210567034490366
# 28 HeadPosY_75% 0.7654534693711074 0.7770268335290244 0.7459028556998145
# 28 HeadPosY_75% 1.0000000000000002 1.0151196181361952 0.9744587823380623
# 29 HeadPosY_75% 0.8959313198423711 0.9148496911033064 0.8864384849092316
# 29 HeadPosY_75% 1.0000000000000002 1.0211158722124636 0.9894045059895779
# 30 HeadPosY_75% 0.8393103693656402 0.918294025914519 0.6860266226513826
# 30 HeadPosY_75% 1.0 1.0941054220604656 0.8173694114727653
# 31 HeadPosY_75% 0.9398616017849102 1.0296061794959246 0.4247153802696629
# 31 HeadPosY_75% 0.9999999999999999 1.0954870137694515 0.45189140556766794
# 32 HeadPosY_75% 0.8927296244902707 0.9440445290269168 0.8121887276788621
# 32 HeadPosY_75% 0.9999999999999999 1.0574809025363596 0.9097813104864805
# 33 HeadPosY_75% 0.7060872478037918 0.7457180123350403 0.6483810585016231
# 33 HeadPosY_75% 1.0000000000000002 1.0561272911449906 0.9182732877818461
# 34 HeadPosY_75% 0.719705951522441 0.7718147713279303 0.6390217360176408
# 34 HeadPosY_75% 1.0000000000000004 1.0724029302456928 0.8878928049238393
# 35 HeadPosY_75% 0.878293053968188 0.917054794342231 0.8278717759802555
# 35 HeadPosY_75% 0.9999999999999999 1.0441330375993694 0.9425917377347734
# 36 HeadPosY_75% 0.8668886956567016 0.8994816575503307 0.78599043500673
# 36 HeadPosY_75% 1.0 1.0375976316878128 0.9066797605560101
# 37 HeadPosY_75% 0.988316424070598 1.0320117466656602 0.9598551452842812
# 37 HeadPosY_75% 1.0000000000000002 1.044211875398259 0.9712022606392668
# 38 HeadPosY_75% 0.6245182574043651 0.6491568799481399 0.5938835070253495
# 38 HeadPosY_75% 1.0000000000000004 1.0394522053625435 0.9509465896059784
# 39 HeadPosY_75% 0.8085557745327497 0.843768305350825 0.7811662835288941
# 39 HeadPosY_75% 1.0000000000000002 1.0435499095141878 0.9661254153806723
# 40 HeadPosY_75% 0.751684721437578 0.8131155479304052 0.0515843159103275
# 40 HeadPosY_75% 1.0000000000000002 1.081724191992811 0.0686249360126328
# 41 HeadPosY_75% 0.9497446037452911 1.023287660533859 0.8852148739029809
# 41 HeadPosY_75% 1.0 1.0774345613531815 0.9320557025669438
# 42 HeadPosY_75% 0.8804745527962117 0.949378952328636 0.7170542736566964
# 42 HeadPosY_75% 1.0 1.0782582521137012 0.8143952274139836
# 43 HeadPosY_75% 0.8290172581220435 0.8938582537769227 0.0075197404903295
# 43 HeadPosY_75% 1.0 1.0782142892920736 0.009070668211858243
# 44 HeadPosY_75% 0.8855722811320053 0.9525082723914304 0.8316337289675587
# 44 HeadPosY_75% 0.9999999999999999 1.075585011732597 0.9390918693892516
# 45 HeadPosY_75% 0.834932835905086 0.8839808491860385 0.7433462897250519
# 45 HeadPosY_75% 1.0 1.0587448608698966 0.8903066902611966
# 46 HeadPosY_75% 0.8517247274428179 0.8986902155377768 0.7738428414850992
# 46 HeadPosY_75% 1.0000000000000002 1.0551416280186747 0.9085597923268613
# 47 HeadPosY_75% 0.6222313631460515 0.6782293567711247 0.6005248510188513
# 47 HeadPosY_75% 0.9999999999999999 1.0899954533663216 0.9651150465681281
# 48 HeadPosY_75% 0.7428040911998071 0.7938579934341553 -0.137051722297577
# 48 HeadPosY_75% 0.9999999999999999 1.068731315348417 -0.18450587970807425
# 49 HeadPosY_75% 0.7670045481881446 0.8000124964528298 0.6786016469283459
# 49 HeadPosY_75% 1.0 1.043034879444533 0.8847426635622588
# 50 HeadPosY_75% 0.8628373282930972 0.9195644986188816 0.8042847212640162
# 50 HeadPosY_75% 1.0000000000000002 1.0657449190776256 0.9321394600012121
# 51 HeadPosY_75% 0.7234608318645663 0.7606070151962073 0.6682087636582325
# 51 HeadPosY_75% 0.9999999999999999 1.051345120144106 0.9236281139589362
# 52 HeadPosY_75% 0.7402387603518793 0.9069118401287136 0.1306290662285965
# 52 HeadPosY_75% 1.0 1.2251612435123023 0.17646882766109243
# 53 HeadPosY_75% 0.831072429961287 0.8710261930858169 0.78536561236524
# 53 HeadPosY_75% 1.0 1.0480749471215054 0.9450026063333901
# 54 HeadPosY_75% 0.9775117653235584 1.0251386976092722 0.9309779255367616
# 54 HeadPosY_75% 0.9999999999999999 1.048722617952275 0.9523956217842616
# 55 HeadPosY_75% 0.7664447678480154 0.8076431429620238 0.6254188264268737
# 55 HeadPosY_75% 1.0000000000000002 1.0537525687985099 0.8159998641296657
# 56 HeadPosY_75% 0.7208439097582546 0.7578708127120165 0.6397324717723355
# 56 HeadPosY_75% 0.9999999999999997 1.0513660481173788 0.8874771127453639
# 57 HeadPosY_75% 0.8808780840855069 0.9063547066067184 0.7882423999437661
# 57 HeadPosY_75% 1.0000000000000002 1.0289218485298794 0.8948371110425439
# 58 HeadPosY_75% 0.8357492274328382 0.8587692556019256 0.8106422916411747
# 58 HeadPosY_75% 0.9999999999999999 1.027544181213063 0.9699587687699286
# 59 HeadPosY_75% 0.7098093683476999 0.7496439812657346 0.6722024217084214
# 59 HeadPosY_75% 1.0000000000000002 1.0561201566143907 0.9470182441705154
# HeadPosY_max
# 0 HeadPosY_max 0.6291231879538374 0.6560006173616039 0.6117916066307175
# 0 HeadPosY_max 1.0000000000000002 1.042722045415593 0.9724512120122465
# 1 HeadPosY_max 0.7365099265896444 0.821155417612354 0.6855050049632067
# 1 HeadPosY_max 1.0000000000000002 1.114927834597769 0.9307478150870113
# 2 HeadPosY_max 0.8694525109033742 0.8935791221836841 0.8496026791802199
# 2 HeadPosY_max 0.9999999999999999 1.0277491996144126 0.9771697344314643
# 3 HeadPosY_max 0.7476856868306411 0.7785320959320733 0.7139416952707355
# 3 HeadPosY_max 0.9999999999999999 1.0412558507468384 0.9548687474506263
# 4 HeadPosY_max 0.7522581093018986 0.7844414304606638 0.7347565068750194
# 4 HeadPosY_max 1.0000000000000002 1.042782285442734 0.9767345779188464
# 5 HeadPosY_max 0.8044382027025075 0.8617701998285342 0.760465812015506
# 5 HeadPosY_max 0.9999999999999999 1.0712696101868608 0.945337764244318
# 6 HeadPosY_max 0.8229854789644252 0.8569074200733434 0.8098018840100173
# 6 HeadPosY_max 1.0 1.0412181526599993 0.9839807684444238
# 7 HeadPosY_max 0.8265973262463605 0.8646350113799618 0.7994103350983813
# 7 HeadPosY_max 1.0 1.0460171886912981 0.9671097518891849
# 8 HeadPosY_max 0.8343102939761788 0.8527212009797444 0.8202568604836774
# 8 HeadPosY_max 1.0 1.022067217840286 0.9831556273559503
# 9 HeadPosY_max 0.721582426054915 0.7481714362431432 0.6936977317246696
# 9 HeadPosY_max 1.0 1.0368481953386774 0.9613561897804268
# 10 HeadPosY_max 0.794713876505832 0.808226766219749 0.7789866601265804
# 10 HeadPosY_max 0.9999999999999999 1.0170034651632482 0.9802102154697481
# 11 HeadPosY_max 0.9466665820965839 0.9669225264043656 0.9318365133446306
# 11 HeadPosY_max 1.0 1.021397126180287 0.9843344330174736
# 12 HeadPosY_max 0.9479536330426588 0.9883398998478796 0.934151619358515
# 12 HeadPosY_max 1.0 1.0426036310189482 0.9854402017112975
# 13 HeadPosY_max 0.7497322828319561 0.787887661330647 0.7352533561108757
# 13 HeadPosY_max 1.0 1.0508920042159142 0.9806878707871705
# 14 HeadPosY_max 0.8679025879502433 0.9022475556603284 0.8425516485351933
# 14 HeadPosY_max 0.9999999999999998 1.0395723761939677 0.970790570546722
# 15 HeadPosY_max 0.8218037882463793 0.8405959653727798 0.8086813304142558
# 15 HeadPosY_max 1.0000000000000002 1.022866987710656 0.9840321278390246
# 16 HeadPosY_max 0.7866353193560128 0.8139352468019295 0.7631086270998487
# 16 HeadPosY_max 1.0000000000000002 1.0347046805224382 0.9700919960275564
# 17 HeadPosY_max 0.8881648750142273 0.900355300059939 0.8781662246117968
# 17 HeadPosY_max 1.0 1.013725407735266 0.988742348764614
# 18 HeadPosY_max 0.5683875973745219 0.5815683733261731 0.5609332731476245
# 18 HeadPosY_max 0.9999999999999999 1.0231897670050074 0.9868851391878883
# 19 HeadPosY_max 0.8120149773616459 0.8417588040098906 0.7766186978110091
# 19 HeadPosY_max 1.0000000000000002 1.0366296527496164 0.9564093267520208
# 20 HeadPosY_max 0.7119003848995891 0.7382978790880387 0.7022815951186149
# 20 HeadPosY_max 1.0 1.0370803201520573 0.9864885734226273
# 21 HeadPosY_max 0.6896721957881984 0.709089486775882 0.658823143871682
# 21 HeadPosY_max 1.0000000000000002 1.0281543769725157 0.9552699788321025
# 22 HeadPosY_max 0.6926332058086963 0.7210032971760992 0.6740563300178338
# 22 HeadPosY_max 0.9999999999999999 1.040959762150414 0.9731793456694403
# 23 HeadPosY_max 0.8893543179898538 0.9256840398282804 0.871453474297566
# 23 HeadPosY_max 1.0 1.0408495479288167 0.9798720899756266
# 24 HeadPosY_max 0.9427398874442675 1.0130766490373282 0.924753768918592
# 24 HeadPosY_max 0.9999999999999999 1.0746088741230002 0.9809214410409267
# 25 HeadPosY_max 0.5892128040514707 0.659224851764502 0.5504042978516029
# 25 HeadPosY_max 1.0000000000000002 1.118823024943829 0.9341349917499796
# 26 HeadPosY_max 0.7960474409973914 0.8213774140794389 0.7768195517574193
# 26 HeadPosY_max 1.0000000000000002 1.03181967779497 0.9758457998233361
# 27 HeadPosY_max 0.8896355135148277 0.9622711718559224 0.8479747050882648
# 27 HeadPosY_max 1.0 1.0816465364046912 0.9531709247285253
# 28 HeadPosY_max 0.7648296282827728 0.7890399287074205 0.7493237036199166
# 28 HeadPosY_max 1.0 1.0316545012501748 0.9797263023169347
# 29 HeadPosY_max 0.8957735396420501 0.9240877795173372 0.8814010302750325
# 29 HeadPosY_max 1.0000000000000002 1.031608703117756 0.9839551976800287
# 30 HeadPosY_max 0.8514255168377273 0.931307950327762 0.7965349522866164
# 30 HeadPosY_max 1.0 1.093821986668576 0.9355309848417752
# 31 HeadPosY_max 0.9515644231985603 1.068977473701347 0.4348075660624487
# 31 HeadPosY_max 1.0000000000000002 1.1233894917047424 0.45693970419879665
# 32 HeadPosY_max 0.898177091867424 0.9458117195106353 0.8687578029115367
# 32 HeadPosY_max 0.9999999999999997 1.0530347835349183 0.9672455585627097
# 33 HeadPosY_max 0.7070279148224222 0.7630557707981619 0.6437696691512652
# 33 HeadPosY_max 1.0 1.079244192203941 0.910529352031249
# 34 HeadPosY_max 0.7227544264509849 0.7750858650620903 0.6533789447979358
# 34 HeadPosY_max 0.9999999999999999 1.0724055594762303 0.9040123738934251
# 35 HeadPosY_max 0.8840841923363296 0.9442577442410416 0.8202780030043523
# 35 HeadPosY_max 1.0 1.0680631465038346 0.9278279264745594
# 36 HeadPosY_max 0.8728483520990824 0.9257580386506422 0.8322869547476061
# 36 HeadPosY_max 0.9999999999999999 1.0606172726617622 0.953529845987643
# 37 HeadPosY_max 0.9905425981268431 1.035445435911206 0.9555055652400049
# 37 HeadPosY_max 1.0 1.045331556532022 0.9646284440940807
# 38 HeadPosY_max 0.6211136963715559 0.654097790500877 0.5850568892375058
# 38 HeadPosY_max 0.9999999999999999 1.0531047605647867 0.9419481371209683
# 39 HeadPosY_max 0.8140275691422093 0.8556071550518468 0.7859425494285704
# 39 HeadPosY_max 1.0 1.051078842395292 0.9654986872947882
# 40 HeadPosY_max 0.763842237329728 0.8450464659748128 0.0536586603464624
# 40 HeadPosY_max 0.9999999999999998 1.1063102099838862 0.07024835460008681
# 41 HeadPosY_max 0.9590087047281372 1.030931507747148 0.891010305921703
# 41 HeadPosY_max 1.0 1.0749970283527297 0.9290951182495153
# 42 HeadPosY_max 0.8915853824840559 1.0585119259673497 0.8082584800007612
# 42 HeadPosY_max 0.9999999999999999 1.187224405831125 0.9065407485134662
# 43 HeadPosY_max 0.8335523698475238 0.9103134272977428 0.0122552621091144
# 43 HeadPosY_max 1.0 1.092089063899201 0.014702450082837834
# 44 HeadPosY_max 0.893902074186991 0.9651148408866748 0.850173527238438
# 44 HeadPosY_max 0.9999999999999999 1.079665064838844 0.9510812781273337
# 45 HeadPosY_max 0.8376802355840602 0.8825004413501191 0.7526219368451764
# 45 HeadPosY_max 1.0000000000000002 1.0535051489364657 0.8984597044007154
# 46 HeadPosY_max 0.8542286627038534 0.8923951410258987 0.8088716131003287
# 46 HeadPosY_max 1.0000000000000002 1.0446794634603322 0.9469029177036065
# 47 HeadPosY_max 0.6165109696206645 0.6695212593331014 0.5916216419070129
# 47 HeadPosY_max 1.0 1.0859843414384884 0.9596287350264573
# 48 HeadPosY_max 0.7718929920648597 0.8229842456507191 0.7141531204774828
# 48 HeadPosY_max 1.0 1.0661895549138065 0.9251970516885776
# 49 HeadPosY_max 0.7702569133399793 0.8085861890712197 0.7368813302028306
# 49 HeadPosY_max 1.0 1.0497616770033746 0.9566695442012643
# 50 HeadPosY_max 0.8674504903831484 0.922734658194154 0.8050131030771882
# 50 HeadPosY_max 1.0000000000000002 1.0637317846077727 0.9280219586037909
# 51 HeadPosY_max 0.7238471423945243 0.7795152231434487 0.6745320367330153
# 51 HeadPosY_max 1.0 1.07690585137184 0.9318708291112789
# 52 HeadPosY_max 0.7533538204358671 1.040498498352469 0.114675975013769
# 52 HeadPosY_max 1.0000000000000002 1.3811551360428078 0.15222060591319633
# 53 HeadPosY_max 0.837840566365844 0.8963276498714007 0.7934270017474293
# 53 HeadPosY_max 0.9999999999999999 1.0698069368486727 0.9469904342170257
# 54 HeadPosY_max 0.9852086925359502 1.0383102474626336 0.941593786636024
# 54 HeadPosY_max 1.0000000000000002 1.0538987884790163 0.9557302871662039
# 55 HeadPosY_max 0.7644152348775478 0.8069370724585897 0.6187580671930449
# 55 HeadPosY_max 1.0 1.0556266223394324 0.8094528195688881
# 56 HeadPosY_max 0.7262616182555799 0.7645991748074182 0.6570683146556783
# 56 HeadPosY_max 1.0000000000000002 1.0527875294359104 0.9047267515443014
# 57 HeadPosY_max 0.8849934969130158 0.9162544756073452 0.8477315661005053
# 57 HeadPosY_max 1.0 1.0353233993282123 0.9578958139890458
# 58 HeadPosY_max 0.8353887387182629 0.8865280915386576 0.8085544752902075
# 58 HeadPosY_max 1.0 1.0612162343711478 0.9678781120879997
# 59 HeadPosY_max 0.7104107181303811 0.7455074786381258 0.6860547105007501
# 59 HeadPosY_max 1.0 1.0494034783147843 0.9657155966146881
# HeadPosY_mean
# 0 HeadPosY_mean 0.6506479835943703 0.6712750488045409 0.5514448694099039
# 0 HeadPosY_mean 1.0000000000000002 1.0317023424805234 0.8475318195309862
# 1 HeadPosY_mean 0.7372919695413 0.7710374466623124 0.4610775037651937
# 1 HeadPosY_mean 1.0 1.0457694895849834 0.6253662359187896
# 2 HeadPosY_mean 0.8836202676748293 0.904040064584283 0.7790794015895985
# 2 HeadPosY_mean 1.0000000000000002 1.023109244611587 0.8816902804183963
# 3 HeadPosY_mean 0.76662420998443 0.7957749556981637 0.614533009039206
# 3 HeadPosY_mean 0.9999999999999998 1.03802481754956 0.8016091861378694
# 4 HeadPosY_mean 0.7721268344404066 0.7855139366546671 0.6898030012525247
# 4 HeadPosY_mean 1.0000000000000002 1.0173379574664863 0.8933804272616097
# 5 HeadPosY_mean 0.8203198425569911 0.8877238494122321 0.6735662250522549
# 5 HeadPosY_mean 1.0000000000000002 1.0821679585917834 0.8211019532975145
# 6 HeadPosY_mean 0.8477775359807918 0.8720707435354584 0.7779162346804489
# 6 HeadPosY_mean 1.0000000000000002 1.0286551678047968 0.9175947718176791
# 7 HeadPosY_mean 0.8320915856173544 0.8588096610513125 0.6760578314079708
# 7 HeadPosY_mean 0.9999999999999999 1.0321095368536086 0.8124800720180131
# 8 HeadPosY_mean 0.8367946364800533 0.8622226512709286 0.4932141708666662
# 8 HeadPosY_mean 1.0 1.0303874017379429 0.58940885775912
# 9 HeadPosY_mean 0.7381688050081496 0.7650008061986859 0.6182564926367908
# 9 HeadPosY_mean 1.0000000000000002 1.0363494108779632 0.8375543486018284
# 10 HeadPosY_mean 0.8033960987294364 0.830679780099786 0.6680547513865387
# 10 HeadPosY_mean 1.0 1.0339604354732348 0.8315384558663668
# 11 HeadPosY_mean 0.9515097951897966 0.973558886505369 0.7303315606181142
# 11 HeadPosY_mean 0.9999999999999998 1.0231727423375334 0.7675502283951116
# 12 HeadPosY_mean 0.9587235119649601 0.9827549029408472 0.8178391497017357
# 12 HeadPosY_mean 0.9999999999999999 1.025066028605717 0.8530500603093861
# 13 HeadPosY_mean 0.7696958759197554 0.8021025503871702 0.6362086066474633
# 13 HeadPosY_mean 1.0000000000000002 1.0421032195718731 0.8265714115815155
# 14 HeadPosY_mean 0.8787651096822814 0.9216677527704644 0.7033955641088885
# 14 HeadPosY_mean 0.9999999999999999 1.048821513980789 0.8004363809610079
# 15 HeadPosY_mean 0.8309535180686639 0.8608041031108344 0.4252044403431745
# 15 HeadPosY_mean 1.0 1.0359232910061569 0.5117066491654696
# 16 HeadPosY_mean 0.8026902509682661 0.825091056782143 0.6904117339346867
# 16 HeadPosY_mean 1.0000000000000002 1.027907160684779 0.8601222365686634
# 17 HeadPosY_mean 0.8998898550363602 0.9252057272782104 0.5587368821746581
# 17 HeadPosY_mean 0.9999999999999999 1.0281321898454199 0.6208947451153144
# 18 HeadPosY_mean 0.598393797343739 0.6177573060666028 0.4142224768715772
# 18 HeadPosY_mean 0.9999999999999999 1.0323591400994097 0.6922238811804275
# 19 HeadPosY_mean 0.8266028448749714 0.8501402796836666 0.7291188512865001
# 19 HeadPosY_mean 1.0000000000000002 1.0284749017676746 0.8820667093116329
# 20 HeadPosY_mean 0.7275682857169083 0.748600840880385 0.5744876481691716
# 20 HeadPosY_mean 0.9999999999999999 1.0289080153387284 0.7895996285807058
# 21 HeadPosY_mean 0.6948265216244763 0.7343797964956065 0.5734454335775063
# 21 HeadPosY_mean 1.0 1.0569253959659688 0.825307347561826
# 22 HeadPosY_mean 0.7157387443652257 0.7291494571900283 0.6646529130608971
# 22 HeadPosY_mean 0.9999999999999999 1.0187368825991059 0.9286250301433164
# 23 HeadPosY_mean 0.886609209338893 0.917581686877943 0.4779042406024516
# 23 HeadPosY_mean 1.0000000000000004 1.0349336293970428 0.5390246746464596
# 24 HeadPosY_mean 0.9487714303721781 0.9799029085558056 0.6158184844689711
# 24 HeadPosY_mean 0.9999999999999999 1.032812411068718 0.649069380416948
# 25 HeadPosY_mean 0.5839903911673816 0.6171448868569982 0.3986190396823283
# 25 HeadPosY_mean 1.0000000000000002 1.0567723308312345 0.6825780795562393
# 26 HeadPosY_mean 0.8179063006283904 0.8541166642383888 0.6705333996935936
# 26 HeadPosY_mean 1.0 1.0442720194014623 0.8198168900012489
# 27 HeadPosY_mean 0.8817775121956978 0.9357175387721854 0.6753124860231368
# 27 HeadPosY_mean 1.0 1.0611719235639983 0.7658536044331111
# 28 HeadPosY_mean 0.7731835573721437 0.7971677671081352 0.4835619642403668
# 28 HeadPosY_mean 1.0 1.0310200721514406 0.625416771515256
# 29 HeadPosY_mean 0.9103609430200243 0.9250494744802932 0.7750460144703635
# 29 HeadPosY_mean 1.0000000000000002 1.016134843627563 0.8513612325010691
# 30 HeadPosY_mean 0.8373529254562219 0.9258431815359168 0.4396788138459033
# 30 HeadPosY_mean 1.0 1.105678565619726 0.5250818388272179
# 31 HeadPosY_mean 0.9344886092730804 1.0388543641052217 0.3059872270085255
# 31 HeadPosY_mean 1.0 1.1116822118498857 0.32743815598410203
# 32 HeadPosY_mean 0.8897298785012402 0.9539131522717428 0.6904459226643747
# 32 HeadPosY_mean 1.0 1.0721379323335978 0.7760174625442932
# 33 HeadPosY_mean 0.7174167571714222 0.7553576797958368 0.645843324977857
# 33 HeadPosY_mean 1.0 1.0528854703283002 0.9002345129548415
# 34 HeadPosY_mean 0.7330954505671083 0.7839836803034697 0.642612007826407
# 34 HeadPosY_mean 1.0 1.0694155579563278 0.8765734493772877
# 35 HeadPosY_mean 0.8853906330505753 0.9268455935391596 0.8205507186258951
# 35 HeadPosY_mean 1.0000000000000002 1.0468210967465885 0.9267668845769499
# 36 HeadPosY_mean 0.8772407296920354 0.9137440545611708 0.7797495745195355
# 36 HeadPosY_mean 0.9999999999999999 1.0416115253585527 0.8888661323252454
# 37 HeadPosY_mean 1.0011252860807942 1.0433706106504073 0.968272952016995
# 37 HeadPosY_mean 1.0 1.0421978399277028 0.9671845926573192
# 38 HeadPosY_mean 0.6393097105023745 0.6602507333580547 0.6015552053592441
# 38 HeadPosY_mean 1.0000000000000002 1.0327556777437725 0.9409448902106263
# 39 HeadPosY_mean 0.8224785097662397 0.8636951492278586 0.781706590088352
# 39 HeadPosY_mean 1.0 1.0501127251012714 0.9504279817724651
# 40 HeadPosY_mean 0.7376194607944455 0.8147221309763635 0.0771129323089562
# 40 HeadPosY_mean 1.0 1.1045290617724148 0.10454297426738511
# 41 HeadPosY_mean 0.9609150081701799 1.014216870497984 0.870402031325398
# 41 HeadPosY_mean 1.0000000000000002 1.0554699030347168 0.9058054291220395
# 42 HeadPosY_mean 0.8713860968425458 0.9465314295462328 0.3935372264603218
# 42 HeadPosY_mean 0.9999999999999999 1.0862365522883313 0.45162210859950364
# 43 HeadPosY_mean 0.8249999145835035 0.911856928111528 0.0333058430277866
# 43 HeadPosY_mean 1.0 1.105281239419126 0.040370723001348266
# 44 HeadPosY_mean 0.8960962737763722 0.9681511351799196 0.8341208187174391
# 44 HeadPosY_mean 1.0 1.0804097322042086 0.9308383966404044
# 45 HeadPosY_mean 0.8481924415494594 0.8988636150710945 0.7507148278574411
# 45 HeadPosY_mean 0.9999999999999999 1.059740185174334 0.8850760642078486
# 46 HeadPosY_mean 0.8635819857207893 0.9188690586750718 0.7674274649686725
# 46 HeadPosY_mean 1.0000000000000002 1.0640206417785998 0.8886561758558902
# 47 HeadPosY_mean 0.6447485589836099 0.6749825901435249 0.617166099209463
# 47 HeadPosY_mean 1.0000000000000004 1.0468927471626712 0.9572198194322011
# 48 HeadPosY_mean 0.7441947911897645 0.8029331471001204 -0.0557332516814816
# 48 HeadPosY_mean 0.9999999999999999 1.0789287382896746 -0.07489067693201579
# 49 HeadPosY_mean 0.7794273165542938 0.8130977113533997 0.7018919021003149
# 49 HeadPosY_mean 0.9999999999999998 1.0431988898566664 0.9005225852273836
# 50 HeadPosY_mean 0.8728328914149263 0.9332626390552484 0.8131439663049687
# 50 HeadPosY_mean 1.0 1.0692340403698137 0.9316147160618599
# 51 HeadPosY_mean 0.7318759346852819 0.7827492496794941 0.6022750968559067
# 51 HeadPosY_mean 0.9999999999999997 1.0695108454632936 0.8229196620802876
# 52 HeadPosY_mean 0.7331430904477773 0.9023045849847712 0.1551871768897258
# 52 HeadPosY_mean 1.0000000000000004 1.230734622941991 0.21167379043965767
# 53 HeadPosY_mean 0.8462138671432425 0.8897067835558419 0.8006806432163025
# 53 HeadPosY_mean 0.9999999999999999 1.051397073602006 0.9461918249098695
# 54 HeadPosY_mean 0.9792583584133336 1.0415463139864456 0.9086687549061678
# 54 HeadPosY_mean 1.0000000000000002 1.0636072748707863 0.9279152402420744
# 55 HeadPosY_mean 0.7760686093612923 0.8229726196455727 0.6427228626659602
# 55 HeadPosY_mean 0.9999999999999999 1.0604379686518728 0.828177889059221
# 56 HeadPosY_mean 0.7347092956248729 0.7721826560555036 0.6390555843800259
# 56 HeadPosY_mean 1.0 1.051004336890497 0.8698074029899224
# 57 HeadPosY_mean 0.8882361495017399 0.9175044532005504 0.7023746127259578
# 57 HeadPosY_mean 1.0000000000000002 1.0329510386570382 0.7907521137480815
# 58 HeadPosY_mean 0.8470645423858385 0.8708508228699754 0.7618080122208499
# 58 HeadPosY_mean 0.9999999999999999 1.0280808359858158 0.8993506091934206
# 59 HeadPosY_mean 0.7243844647969458 0.7507032340615596 0.6551581388763354
# 59 HeadPosY_mean 0.9999999999999998 1.0363325975964865 0.9044342758786035
# HeadPosY_min
# 0 HeadPosY_min 0.6823101275144546 0.7424422550100125 0.1566130164452129
# 0 HeadPosY_min 1.0 1.088130199260869 0.22953347771009755
# 1 HeadPosY_min 0.7336798116100791 0.8213586016817036 0.1887798062189349
# 1 HeadPosY_min 1.0000000000000002 1.1195055236414522 0.25730543928236593
# 2 HeadPosY_min 0.8755857311419722 0.9290786645746804 0.3896363311985514
# 2 HeadPosY_min 0.9999999999999999 1.0610938843908986 0.4450007775827649
# 3 HeadPosY_min 0.775394289944627 0.8401331223561859 0.1854342399903959
# 3 HeadPosY_min 0.9999999999999999 1.083491500067897 0.23914831769477984
# 4 HeadPosY_min 0.7879185848302097 0.8338471593950136 0.3549426510090055
# 4 HeadPosY_min 0.9999999999999999 1.0582910156570315 0.450481379475892
# 5 HeadPosY_min 0.8085584552871286 0.9178489668177856 0.1538226824888411
# 5 HeadPosY_min 1.0 1.1351671123046345 0.19024311907568497
# 6 HeadPosY_min 0.8596944999769349 0.8964650212005356 0.5394906869373688
# 6 HeadPosY_min 1.0000000000000002 1.0427716138984107 0.6275376740828783
# 7 HeadPosY_min 0.8089391423189812 0.8839931371290324 0.1236817401946481
# 7 HeadPosY_min 1.0000000000000002 1.0927807679016426 0.1528937514880172
# 8 HeadPosY_min 0.8075534237378192 0.8929969037047165 0.3293077604131062
# 8 HeadPosY_min 1.0000000000000002 1.1058053590701356 0.4077844892154398
# 9 HeadPosY_min 0.7596298340361274 0.8099038097604165 0.3233902849358648
# 9 HeadPosY_min 0.9999999999999999 1.0661822027936545 0.425720884628242
# 10 HeadPosY_min 0.7775063679417001 0.8709126651315802 0.2776044645343302
# 10 HeadPosY_min 1.0000000000000002 1.1201357326977983 0.35704461851448893
# 11 HeadPosY_min 0.9157585089762552 0.9794163891894778 0.456322561604938
# 11 HeadPosY_min 0.9999999999999999 1.0695138287979296 0.49830010546674597
# 12 HeadPosY_min 0.9296007579837565 0.9877031891674684 0.2650308712478053
# 12 HeadPosY_min 1.0000000000000002 1.0625025643371162 0.28510182352114255
# 13 HeadPosY_min 0.7842965696205134 0.8471610623777615 0.170563018862891
# 13 HeadPosY_min 1.0 1.08015398153235 0.21747260598808807
# 14 HeadPosY_min 0.8623317143227139 0.9373654645526712 0.2203963658130317
# 14 HeadPosY_min 1.0 1.0870126298078806 0.25558188589426256
# 15 HeadPosY_min 0.808744241340961 0.8943224582283589 0.2128957280462327
# 15 HeadPosY_min 1.0000000000000002 1.1058161684656975 0.26324234184744855
# 16 HeadPosY_min 0.7982771820656088 0.8593161472549351 0.2685798559063875
# 16 HeadPosY_min 0.9999999999999998 1.0764633720725711 0.33644937114626616
# 17 HeadPosY_min 0.878043926153552 0.948370068145174 0.2952876953525558
# 17 HeadPosY_min 1.0000000000000002 1.0800941045167294 0.336301734522694
# 18 HeadPosY_min 0.649705112749945 0.7010165919409621 0.1258768251385163
# 18 HeadPosY_min 0.9999999999999999 1.078976566728613 0.1937445506711952
# 19 HeadPosY_min 0.8127509174671405 0.8818422373359522 0.3701973658980673
# 19 HeadPosY_min 1.0 1.0850092179337407 0.45548686312376185
# 20 HeadPosY_min 0.7269916109350189 0.7977237144205327 0.1328764199690204
# 20 HeadPosY_min 1.0000000000000002 1.0972942499220064 0.1827757266663939
# 21 HeadPosY_min 0.6789287268507326 0.7955061200602251 0.2558136820569939
# 21 HeadPosY_min 1.0000000000000002 1.1717078517950574 0.37679018715794654
# 22 HeadPosY_min 0.7558134041629638 0.7856603345732966 0.4302366489981642
# 22 HeadPosY_min 0.9999999999999999 1.0394898135517816 0.5692365954724444
# 23 HeadPosY_min 0.8276382147642877 0.9354813430285004 0.1701653525057982
# 23 HeadPosY_min 1.0 1.1303022580886102 0.20560354690033433
# 24 HeadPosY_min 0.920555849196914 0.9833346950140808 0.3515562343580398
# 24 HeadPosY_min 1.0000000000000002 1.0681966725559722 0.38189560651288545
# 25 HeadPosY_min 0.5546574483658998 0.6903621348264024 0.02771409372921
# 25 HeadPosY_min 1.0 1.2446639576558614 0.04996614362767449
# 26 HeadPosY_min 0.8272773554714835 0.8918714328827562 0.2212000353481206
# 26 HeadPosY_min 1.0 1.078080316092369 0.267383162231068
# 27 HeadPosY_min 0.8338491185479261 0.954489294688278 0.3585574965527245
# 27 HeadPosY_min 0.9999999999999999 1.1446786636297417 0.43000284892921686
# 28 HeadPosY_min 0.7658466013838012 0.8404832688341288 -0.0630305344402408
# 28 HeadPosY_min 0.9999999999999998 1.0974564192299963 -0.08230177469789839
# 29 HeadPosY_min 0.9059020245691669 0.9486201727722764 0.3832920104910554
# 29 HeadPosY_min 1.0000000000000002 1.0471553733676946 0.42310536911907576
# 30 HeadPosY_min 0.815740862705343 0.9330803386083176 0.1713883641323286
# 30 HeadPosY_min 1.0 1.143844057920339 0.21010148193867847
# 31 HeadPosY_min 0.9017514965982993 1.0292122204455532 0.3250526470240051
# 31 HeadPosY_min 0.9999999999999999 1.141347948218636 0.3604680981957997
# 32 HeadPosY_min 0.8248466719688847 0.9550645353306132 0.2456452616011031
# 32 HeadPosY_min 1.0000000000000002 1.1578691747047998 0.2978071803511737
# 33 HeadPosY_min 0.7421371273649479 0.8031593216495567 0.5950472614377014
# 33 HeadPosY_min 0.9999999999999999 1.082224958211262 0.8018023078167403
# 34 HeadPosY_min 0.7645281609473298 0.8303873787200979 0.6023753270118
# 34 HeadPosY_min 0.9999999999999999 1.0861436126710646 0.7879046944005234
# 35 HeadPosY_min 0.8698577793932685 0.939649753480206 0.4829920516749507
# 35 HeadPosY_min 1.0 1.0802337758427796 0.5552540462555164
# 36 HeadPosY_min 0.8686667255802012 0.9336889265342668 0.7253350985162128
# 36 HeadPosY_min 1.0 1.0748528739956464 0.8349981381314519
# 37 HeadPosY_min 0.9835784080784908 1.0375407045280611 0.8829010135906854
# 37 HeadPosY_min 0.9999999999999999 1.0548632381580951 0.8976417196017064
# 38 HeadPosY_min 0.6860418552872397 0.7294868353261115 0.5300200583910937
# 38 HeadPosY_min 1.0 1.063327010887232 0.7725768541763082
# 39 HeadPosY_min 0.8341770196087587 0.8832511600686288 0.7223338429909847
# 39 HeadPosY_min 0.9999999999999999 1.058829408274621 0.8659239298269927
# 40 HeadPosY_min 0.7166737529644346 0.8371235300100541 0.2034184300432347
# 40 HeadPosY_min 1.0 1.1680677945123477 0.2838368632893543
# ...
# 16 RightTouchPosY_min 0.43081865445897266 0.6260685433429266 0.1661743264578249
# 16 RightTouchPosY_min 1.0 1.4532066726060207 0.385717574524503
# 17 RightTouchPosY_min 0.4670356262594083 0.5531010084000855 0.1795830216598804
# 17 RightTouchPosY_min 1.0000000000000002 1.1842801219041765 0.3845167511056931
# 18 RightTouchPosY_min 0.40212049782970893 0.4703156398670634 0.1956284662854265
# 18 RightTouchPosY_min 1.0 1.1695888232641996 0.48649215183323424
# 19 RightTouchPosY_min 0.4563911191092652 0.6373223381436224 0.235032085457266
# 19 RightTouchPosY_min 1.0 1.396438956541221 0.5149795331600145
# 20 RightTouchPosY_min 0.38805289219650624 0.5550584401703599 0.0624540877444513
# 20 RightTouchPosY_min 1.0 1.4303680022291487 0.16094220401487216
# 21 RightTouchPosY_min 0.4172353262647232 0.6312001715229144 0.1762886825231634
# 21 RightTouchPosY_min 1.0 1.5128157463887346 0.42251619512033733
# 22 RightTouchPosY_min 0.41149348380144796 0.4887901403720781 0.2917496775158318
# 22 RightTouchPosY_min 0.9999999999999998 1.1878441812894587 0.7090019380637521
# 23 RightTouchPosY_min 0.4130874944734878 0.6117760322289255 0.09638418320999
# 23 RightTouchPosY_min 1.0 1.480984150848434 0.23332631585189753
# 24 RightTouchPosY_min 0.5988106296064698 0.711887515732786 0.258863162226871
# 24 RightTouchPosY_min 0.9999999999999998 1.1888358030662027 0.43229553623153344
# 25 RightTouchPosY_min 0.2712630206544306 0.4944905293341568 0.0740868433808546
# 25 RightTouchPosY_min 1.0 1.8229190552445476 0.27311810950905785
# 26 RightTouchPosY_min 0.4751861386819852 0.7120984045621006 0.105078554491277
# 26 RightTouchPosY_min 1.0 1.4985672909930294 0.22113135451032176
# 27 RightTouchPosY_min 0.43594946251573535 0.5784178928307703 0.2142927667368245
# 27 RightTouchPosY_min 1.0000000000000002 1.3268003348206734 0.49155414827261024
# 28 RightTouchPosY_min 0.3997455061773918 0.6270526912130613 0.0934566628248686
# 28 RightTouchPosY_min 1.0 1.5686297444824788 0.23379040259528547
# 29 RightTouchPosY_min 0.42799637612044 0.4949218928486639 0.1258357668093574
# 29 RightTouchPosY_min 1.0000000000000002 1.1563693537194595 0.29401129035248347
# 30 RightTouchPosY_min 0.6545882113357432 0.8954758275069968 0.057070671083403
# 30 RightTouchPosY_min 1.0 1.3679987081950373 0.08718560782960852
# 31 RightTouchPosY_min 0.6704071208849919 0.9457823991543998 0.2143375007309215
# 31 RightTouchPosY_min 1.0 1.4107582835723613 0.3197124464429593
# 32 RightTouchPosY_min 0.648857999710933 0.7784772612315077 0.4562493549517815
# 32 RightTouchPosY_min 1.0000000000000002 1.19976522070826 0.7031574784545171
# 33 RightTouchPosY_min 0.6853076202335263 0.827339563926635 0.5098451532794331
# 33 RightTouchPosY_min 1.0000000000000002 1.2072528299695686 0.7439653933888808
# 34 RightTouchPosY_min 0.659692519826479 0.8207317139414451 0.456260857978835
# 34 RightTouchPosY_min 0.9999999999999999 1.2441125058645877 0.6916265445890559
# 35 RightTouchPosY_min 0.6297447510249675 0.9080588609894328 0.304943010489163
# 35 RightTouchPosY_min 1.0 1.441947486678505 0.4842327149100333
# 36 RightTouchPosY_min 0.6796333261013375 0.9520004243338868 0.4788291580007866
# 36 RightTouchPosY_min 1.0000000000000004 1.400755948497937 0.7045404332179411
# 37 RightTouchPosY_min 0.5229532679940095 0.8908171015503205 -2.9818558919942446
# 37 RightTouchPosY_min 0.9999999999999998 1.703435385282887 -5.70195479116578
# 38 RightTouchPosY_min 0.5851990018354785 0.6974831696335423 0.3496277971926862
# 38 RightTouchPosY_min 0.9999999999999998 1.1918734779893407 0.5974511167928817
# 39 RightTouchPosY_min 0.6438205472394706 0.7976937069814747 0.4566097831327919
# 39 RightTouchPosY_min 1.0 1.2390000760332531 0.7092190286417728
# 40 RightTouchPosY_min 0.6005946319420102 0.8147693115853695 0.1784748967203911
# 40 RightTouchPosY_min 1.0 1.356604385475158 0.2971636561973527
# 41 RightTouchPosY_min 0.7138795737446816 0.9796843761093632 0.4768014299540741
# 41 RightTouchPosY_min 1.0 1.3723384337366493 0.6679017687156877
# 42 RightTouchPosY_min 0.6347170196764604 0.8857685507879415 0.1605090856339653
# 42 RightTouchPosY_min 0.9999999999999999 1.3955330065663776 0.25288290790718504
# 43 RightTouchPosY_min 0.6243400857167232 0.9219583520124388 0.3152497227291187
# 43 RightTouchPosY_min 1.0000000000000002 1.4766925480270245 0.5049326960437304
# 44 RightTouchPosY_min 0.6607030074983758 0.9279271449390994 0.4596619196443264
# 44 RightTouchPosY_min 1.0000000000000002 1.4044542470792074 0.6957164027219239
# 45 RightTouchPosY_min 0.7578697160765349 0.8663731690615862 0.5759428248430876
# 45 RightTouchPosY_min 0.9999999999999998 1.1431690047555534 0.7599496491622908
# 46 RightTouchPosY_min 0.6776442929595189 0.900811953945714 0.4478144408362573
# 46 RightTouchPosY_min 1.0000000000000002 1.3293286216748625 0.6608399797487985
# 47 RightTouchPosY_min 0.6239540739514698 0.7827845058059931 0.3691126469072354
# 47 RightTouchPosY_min 0.9999999999999999 1.2545546835661447 0.5915702169707195
# 48 RightTouchPosY_min 0.602095223123044 0.7619256834156066 0.2565210181073622
# 48 RightTouchPosY_min 1.0000000000000004 1.2654571140151691 0.4260472567392212
# 49 RightTouchPosY_min 0.6483608452722506 0.8206550270944217 0.4155094674705578
# 49 RightTouchPosY_min 1.0 1.265738104141412 0.6408614439017872
# 50 RightTouchPosY_min 0.6740770658078592 0.8278572001440434 0.477835424274774
# 50 RightTouchPosY_min 1.0 1.2281343515995218 0.7088735821357517
# 51 RightTouchPosY_min 0.5886287784647998 0.7650251101494723 0.2900165547731012
# 51 RightTouchPosY_min 0.9999999999999999 1.2996733053805678 0.4926985655194979
# 52 RightTouchPosY_min 0.5278516616495362 0.9364074321057794 0.1117451977258515
# 52 RightTouchPosY_min 1.0000000000000002 1.7739973180713433 0.21169810733691316
# 53 RightTouchPosY_min 0.5866007521914598 0.8507993485452345 0.4268712629141449
# 53 RightTouchPosY_min 1.0 1.4503891196299443 0.7277032314046863
# 54 RightTouchPosY_min 0.716108849736703 1.0077006375552746 0.4814505700548726
# 54 RightTouchPosY_min 1.0000000000000002 1.4071891974603907 0.672314788780911
# 55 RightTouchPosY_min 0.6337384955084407 0.7698308192296103 0.4600210697112197
# 55 RightTouchPosY_min 1.0 1.2147452374847205 0.7258846874090398
# 56 RightTouchPosY_min 0.6083652994999486 0.799042117374971 0.404660195787911
# 56 RightTouchPosY_min 0.9999999999999999 1.3134248748765767 0.665159890152389
# 57 RightTouchPosY_min 0.6038637528221026 0.8590304034590881 0.0049602330768903
# 57 RightTouchPosY_min 0.9999999999999999 1.422556660247427 0.00821415932602197
# 58 RightTouchPosY_min 0.6451373775633245 0.8218820166467973 0.4381934368201032
# 58 RightTouchPosY_min 0.9999999999999999 1.2739643450066946 0.6792250023943027
# 59 RightTouchPosY_min 0.5589005257628928 0.7548960557717876 0.4055925800363048
# 59 RightTouchPosY_min 1.0000000000000002 1.350680525378578 0.7256972597810237
# RightTouchPosY_std
# 0 RightTouchPosY_std 0.3533870522780949 0.6398833545490875 0.0373276974982399
# 0 RightTouchPosY_std 1.0000000000000002 1.8107153344303537 0.10562836769940623
# 1 RightTouchPosY_std 0.42557225102186397 0.8662559377847845 0.0169973923262079
# 1 RightTouchPosY_std 1.0000000000000002 2.035508508143498 0.03994008604977079
# 2 RightTouchPosY_std 0.2024681787025748 0.6146343779521042 0.0483430836022788
# 2 RightTouchPosY_std 0.9999999999999999 3.0357085340062273 0.23876879770472303
# 3 RightTouchPosY_std 0.327147746682758 0.7642620538254044 0.0562113534957373
# 3 RightTouchPosY_std 0.9999999999999999 2.3361373005772994 0.17182252992941022
# 4 RightTouchPosY_std 0.3220302553125087 0.6395038192788971 0.0808943555325974
# 4 RightTouchPosY_std 0.9999999999999999 1.9858501141711102 0.2512011036170961
# 5 RightTouchPosY_std 0.41445865584378705 0.772176293164775 0.042938723511255
# 5 RightTouchPosY_std 1.0000000000000002 1.8630960706869992 0.10360194655323827
# 6 RightTouchPosY_std 0.2569831353395067 0.5079316469786767 0.0142668522954953
# 6 RightTouchPosY_std 1.0000000000000002 1.9765174329733186 0.055516687025578604
# 7 RightTouchPosY_std 0.3943148409573507 0.7582163977688435 0.0101475455397291
# 7 RightTouchPosY_std 1.0000000000000002 1.9228705567560735 0.025734627474563315
# 8 RightTouchPosY_std 0.48623834465447524 0.8416604324458085 0.0309979891217323
# 8 RightTouchPosY_std 1.0000000000000002 1.7309626887692269 0.06375060597855506
# 9 RightTouchPosY_std 0.3907301688159785 0.6407049991775281 0.0243123738608665
# 9 RightTouchPosY_std 0.9999999999999999 1.6397633208591063 0.062222924670853504
# 10 RightTouchPosY_std 0.4555987744227134 0.8492783367390344 0.0074913363733507
# 10 RightTouchPosY_std 0.9999999999999998 1.864092671924217 0.016442836973920592
# 11 RightTouchPosY_std 0.4676420067889367 0.833751787394465 0.1015909460468092
# 11 RightTouchPosY_std 1.0000000000000002 1.7828847179906284 0.21724084785364622
# 12 RightTouchPosY_std 0.19604265194819023 0.6671378786560462 0.0083723851644407
# 12 RightTouchPosY_std 1.0000000000000002 3.4030241481958536 0.04270695729342275
# 13 RightTouchPosY_std 0.3178677814694318 0.5977613184882159 0.0247355316118289
# 13 RightTouchPosY_std 1.0 1.8805344653833704 0.07781704549445705
# 14 RightTouchPosY_std 0.42223017489576925 0.7322850854114379 0.0157545340920217
# 14 RightTouchPosY_std 1.0000000000000002 1.7343267462876335 0.03731266742342806
# 15 RightTouchPosY_std 0.210500643019187 0.6147527702466627 0.0208209532160361
# 15 RightTouchPosY_std 1.0 2.9204317926507635 0.09891158961513614
# 16 RightTouchPosY_std 0.24109419013000252 0.52871850049972 0.0034307074914213
# 16 RightTouchPosY_std 1.0 2.192995609784811 0.014229739379333025
# 17 RightTouchPosY_std 0.31026258997082884 0.6330925495960654 0.0276708846447418
# 17 RightTouchPosY_std 1.0 2.040505591265738 0.08918537245287433
# 18 RightTouchPosY_std 0.19316950963337243 0.3846158119133372 0.0592926961631485
# 18 RightTouchPosY_std 1.0000000000000002 1.9910792994366542 0.30694645482966504
# 19 RightTouchPosY_std 0.3353113804314037 0.583883782717082 0.0212183577891774
# 19 RightTouchPosY_std 1.0000000000000002 1.7413181203867012 0.06327956349670674
# 20 RightTouchPosY_std 0.39130855136251713 0.6910370608683918 0.0051983275965762
# 20 RightTouchPosY_std 0.9999999999999999 1.7659646293499969 0.013284472262300118
# 21 RightTouchPosY_std 0.3003772402461674 0.7703634227300409 0.0121709155464367
# 21 RightTouchPosY_std 1.0 2.5646531078676498 0.04051876745542472
# 22 RightTouchPosY_std 0.20106391544715077 0.3400043400641696 0.0137936127178238
# 22 RightTouchPosY_std 1.0 1.691026156075922 0.06860312397253311
# 23 RightTouchPosY_std 0.3996615269486064 0.725781165340207 0.0985093762752293
# 23 RightTouchPosY_std 1.0000000000000002 1.8159895721800043 0.24648200948273136
# 24 RightTouchPosY_std 0.29621051906768403 0.6951714430688944 0.0296584067682049
# 24 RightTouchPosY_std 0.9999999999999997 2.346883038647415 0.10012610916571792
# 25 RightTouchPosY_std 0.5213143002373456 0.8477160838931681 0.0776968239279347
# 25 RightTouchPosY_std 0.9999999999999999 1.6261132363091082 0.14904026974238122
# 26 RightTouchPosY_std 0.32751864531270586 0.7848467046630753 0.0253901547828206
# 26 RightTouchPosY_std 0.9999999999999998 2.3963420583696085 0.07752277663025497
# 27 RightTouchPosY_std 0.41544886612650517 0.7724338496170634 0.0183585661375106
# 27 RightTouchPosY_std 1.0 1.8592753828382227 0.04418971294513143
# 28 RightTouchPosY_std 0.49524503891373917 0.7781561751355802 0.0362712097999787
# 28 RightTouchPosY_std 0.9999999999999999 1.5712548617193074 0.07323891599103197
# 29 RightTouchPosY_std 0.48298583290235225 0.8264035043910205 0.0077281749028598
# 29 RightTouchPosY_std 0.9999999999999999 1.7110305273862945 0.016000831445551415
# 30 RightTouchPosY_std 0.28028809012020933 0.9314478231544226 0.0605168014962433
# 30 RightTouchPosY_std 0.9999999999999999 3.323180170641376 0.21590928629999578
# 31 RightTouchPosY_std 0.30107375709259904 0.6635969022418344 0.0436639321875945
# 31 RightTouchPosY_std 0.9999999999999999 2.204100777995529 0.14502736010354136
# 32 RightTouchPosY_std 0.22297014430255097 0.6794904076390395 0.0052115548551743
# 32 RightTouchPosY_std 1.0000000000000002 3.047450185604358 0.023373330413701827
# 33 RightTouchPosY_std 0.10968502228191766 0.3445217198719613 0.0110292174324878
# 33 RightTouchPosY_std 1.0 3.14100970856764 0.10055354143193754
# 34 RightTouchPosY_std 0.14101139642131094 0.507012959189643 0.0055521985429044
# 34 RightTouchPosY_std 1.0000000000000002 3.595545977537873 0.03937411219101508
# 35 RightTouchPosY_std 0.2623437931066524 0.7797581458483837 0.028875162629295
# 35 RightTouchPosY_std 0.9999999999999998 2.9722759460574824 0.11006611701141404
# 36 RightTouchPosY_std 0.25978017825074934 0.7557231514877932 0.015171177323406
# 36 RightTouchPosY_std 1.0000000000000002 2.909087046504147 0.05840005740839174
# 37 RightTouchPosY_std 0.3740353097404499 3.4652811676824387 0.0056545182028393
# 37 RightTouchPosY_std 0.9999999999999999 9.26458298840038 0.015117605358603913
# 38 RightTouchPosY_std 0.17349023537012345 0.586703087661206 0.0080042938331343
# 38 RightTouchPosY_std 1.0 3.3817643189516446 0.046136854999694756
# 39 RightTouchPosY_std 0.18970855119519703 0.5901757625402181 0.0084634930921818
# 39 RightTouchPosY_std 1.0000000000000002 3.11096025362066 0.04461313440464499
# 40 RightTouchPosY_std 0.25428878168760305 0.74860739749929 0.0200252290905739
# 40 RightTouchPosY_std 0.9999999999999999 2.9439261635181513 0.07874995097178587
# 41 RightTouchPosY_std 0.2486037790698086 0.6390429917755678 0.0167892714935486
# 41 RightTouchPosY_std 1.0000000000000002 2.5705280674599997 0.0675342569464084
# 42 RightTouchPosY_std 0.2563128488398407 0.8495621055171045 0.0327441939683585
# 42 RightTouchPosY_std 1.0 3.3145513748628375 0.1277508877005967
# 43 RightTouchPosY_std 0.28722953144311253 0.90252896719102 0.0085357658578356
# 43 RightTouchPosY_std 1.0 3.142187234914496 0.02971757748915925
# 44 RightTouchPosY_std 0.2992013016788625 0.7279148274776411 0.0264196226659376
# 44 RightTouchPosY_std 1.0 2.4328598284606517 0.08830049374014488
# 45 RightTouchPosY_std 0.0912701470872637 0.3604616685805039 0.0080518004530277
# 45 RightTouchPosY_std 0.9999999999999999 3.949392874713626 0.08821943110631064
# 46 RightTouchPosY_std 0.19595422012438027 0.5181452673434488 0.0066267849424647
# 46 RightTouchPosY_std 0.9999999999999998 2.6442159143832704 0.03381802616069409
# 47 RightTouchPosY_std 0.15075744509587666 0.5396167585835338 0.0071717337304923
# 47 RightTouchPosY_std 1.0000000000000002 3.5793705461136973 0.04757134034694816
# 48 RightTouchPosY_std 0.22573025278133987 0.7609330871656046 0.0221999491619947
# 48 RightTouchPosY_std 1.0000000000000002 3.3709840740873327 0.0983472480469834
# 49 RightTouchPosY_std 0.22167390093984324 0.7736107452050768 0.0262373916124381
# 49 RightTouchPosY_std 0.9999999999999998 3.4898593922205365 0.11836030990205866
# 50 RightTouchPosY_std 0.1861884856985486 0.5750768061779478 0.0226451435940158
# 50 RightTouchPosY_std 1.0 3.0886808280348492 0.1216248336144684
# 51 RightTouchPosY_std 0.16374389328416522 0.5963472931720439 0.0062920592860955
# 51 RightTouchPosY_std 0.9999999999999999 3.641951349826085 0.03842622255949481
# 52 RightTouchPosY_std 0.31711651974698646 0.7930596682285844 0.012866531333217
# 52 RightTouchPosY_std 0.9999999999999999 2.5008462784005463 0.040573513305086246
# 53 RightTouchPosY_std 0.2157867163345498 0.6383511194521971 0.0079766939352242
# 53 RightTouchPosY_std 1.0 2.9582503051879945 0.036965639362421886
# 54 RightTouchPosY_std 0.32841106435409706 0.7149473174213448 0.0159063000844366
# 54 RightTouchPosY_std 1.0000000000000002 2.176989130459013 0.04843411751586487
# 55 RightTouchPosY_std 0.18355451555270766 0.5541812994051415 0.0188561792436563
# 55 RightTouchPosY_std 1.0 3.019164621128639 0.10272795080457582
# 56 RightTouchPosY_std 0.21981208723255133 0.8165701699726714 0.0228492430593267
# 56 RightTouchPosY_std 1.0000000000000002 3.71485563079512 0.10394898363870786
# 57 RightTouchPosY_std 0.34801098936128655 0.871529514124324 0.0095023201781886
# 57 RightTouchPosY_std 1.0 2.5043160726730624 0.02730465550995516
# 58 RightTouchPosY_std 0.22508726108525132 0.6505749218930611 0.0097799484482989
# 58 RightTouchPosY_std 0.9999999999999999 2.890323151813808 0.043449586623184176
# 59 RightTouchPosY_std 0.2630483890018528 0.6771229219551735 0.0068484133013566
# 59 RightTouchPosY_std 1.0000000000000002 2.574138258457094 0.026034804194555863

# %% [markdown]
# ### 2.1. Training On Cooking Similator

# %%
evaluator = ClassifierEvaluator()
X, y, fX, fy, X_train, y_train, X_test, y_test, fX_train, fy_train, fX_test, fy_test = evaluator.split_data(mov_slow, mov_fast, id_range=range(0,30), train_minutes=8, test_minutes=2)
# Out:
# Size of the training set:  (1437, 462)
# Size of the slow testing set:  (360, 462)
# Size of the fast training set:  (1440, 462)
# Size of the fast testing set:  (360, 462)

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast, best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(X_train,y_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Slow)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:16<00:04,  4.83s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:32<00:00,  5.48s/it]
# <style type="text/css">
# #T_ab1d3_row0_col1, #T_ab1d3_row0_col4, #T_ab1d3_row0_col6, #T_ab1d3_row0_col7, #T_ab1d3_row0_col10, #T_ab1d3_row0_col14, #T_ab1d3_row0_col15, #T_ab1d3_row1_col13, #T_ab1d3_row2_col1, #T_ab1d3_row2_col4, #T_ab1d3_row2_col7, #T_ab1d3_row2_col10, #T_ab1d3_row3_col1, #T_ab1d3_row3_col4, #T_ab1d3_row3_col7, #T_ab1d3_row3_col9, #T_ab1d3_row3_col10, #T_ab1d3_row4_col1, #T_ab1d3_row4_col2, #T_ab1d3_row4_col3, #T_ab1d3_row4_col4, #T_ab1d3_row4_col5, #T_ab1d3_row4_col7, #T_ab1d3_row4_col10, #T_ab1d3_row4_col11, #T_ab1d3_row4_col12, #T_ab1d3_row5_col1, #T_ab1d3_row5_col2, #T_ab1d3_row5_col4, #T_ab1d3_row5_col5, #T_ab1d3_row5_col7, #T_ab1d3_row5_col8, #T_ab1d3_row5_col10, #T_ab1d3_row5_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ab1d3_row0_col2, #T_ab1d3_row0_col5, #T_ab1d3_row0_col8, #T_ab1d3_row0_col11, #T_ab1d3_row0_col13, #T_ab1d3_row1_col1, #T_ab1d3_row1_col3, #T_ab1d3_row1_col4, #T_ab1d3_row1_col7, #T_ab1d3_row1_col10, #T_ab1d3_row1_col12, #T_ab1d3_row2_col6, #T_ab1d3_row2_col9, #T_ab1d3_row3_col15, #T_ab1d3_row4_col13, #T_ab1d3_row5_col13, #T_ab1d3_row5_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ab1d3_row0_col3, #T_ab1d3_row0_col12, #T_ab1d3_row5_col3, #T_ab1d3_row5_col12 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_ab1d3_row0_col9 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_ab1d3_row1_col2, #T_ab1d3_row1_col11 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_ab1d3_row1_col5 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_ab1d3_row1_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ab1d3_row1_col8 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_ab1d3_row1_col9 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_ab1d3_row1_col14, #T_ab1d3_row2_col14, #T_ab1d3_row3_col14, #T_ab1d3_row4_col14 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ab1d3_row1_col15 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_ab1d3_row2_col2, #T_ab1d3_row2_col11 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_ab1d3_row2_col3, #T_ab1d3_row2_col12 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_ab1d3_row2_col5, #T_ab1d3_row3_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_ab1d3_row2_col8 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_ab1d3_row2_col13, #T_ab1d3_row5_col9 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_ab1d3_row2_col15 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_ab1d3_row3_col2, #T_ab1d3_row3_col11 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_ab1d3_row3_col3, #T_ab1d3_row3_col12 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_ab1d3_row3_col6 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_ab1d3_row3_col8, #T_ab1d3_row4_col8 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_ab1d3_row3_col13 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_ab1d3_row4_col6 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_ab1d3_row4_col9 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_ab1d3_row4_col15 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_ab1d3_row5_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_ab1d3_row5_col15 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# </style>
# <table id="T_ab1d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab1d3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ab1d3_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_ab1d3_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_ab1d3_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_ab1d3_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_ab1d3_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_ab1d3_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_ab1d3_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_ab1d3_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_ab1d3_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_ab1d3_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_ab1d3_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_ab1d3_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_ab1d3_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_ab1d3_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_ab1d3_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab1d3_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ab1d3_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_ab1d3_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_ab1d3_row0_col2" class="data row0 col2" >0.083333</td>
#       <td id="T_ab1d3_row0_col3" class="data row0 col3" >0.041667</td>
#       <td id="T_ab1d3_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_ab1d3_row0_col5" class="data row0 col5" >0.080629</td>
#       <td id="T_ab1d3_row0_col6" class="data row0 col6" >0.041467</td>
#       <td id="T_ab1d3_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_ab1d3_row0_col8" class="data row0 col8" >0.088936</td>
#       <td id="T_ab1d3_row0_col9" class="data row0 col9" >0.049792</td>
#       <td id="T_ab1d3_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_ab1d3_row0_col11" class="data row0 col11" >0.083333</td>
#       <td id="T_ab1d3_row0_col12" class="data row0 col12" >0.041667</td>
#       <td id="T_ab1d3_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_ab1d3_row0_col14" class="data row0 col14" >33.040016</td>
#       <td id="T_ab1d3_row0_col15" class="data row0 col15" >34.541834</td>
#     </tr>
#     <tr>
#       <th id="T_ab1d3_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_ab1d3_row1_col0" class="data row1 col0" >LogisticRegression</td>
#       <td id="T_ab1d3_row1_col1" class="data row1 col1" >0.972860</td>
#       <td id="T_ab1d3_row1_col2" class="data row1 col2" >0.741667</td>
#       <td id="T_ab1d3_row1_col3" class="data row1 col3" >0.036111</td>
#       <td id="T_ab1d3_row1_col4" class="data row1 col4" >0.972668</td>
#       <td id="T_ab1d3_row1_col5" class="data row1 col5" >0.724727</td>
#       <td id="T_ab1d3_row1_col6" class="data row1 col6" >0.015486</td>
#       <td id="T_ab1d3_row1_col7" class="data row1 col7" >0.973331</td>
#       <td id="T_ab1d3_row1_col8" class="data row1 col8" >0.736378</td>
#       <td id="T_ab1d3_row1_col9" class="data row1 col9" >0.036637</td>
#       <td id="T_ab1d3_row1_col10" class="data row1 col10" >0.972917</td>
#       <td id="T_ab1d3_row1_col11" class="data row1 col11" >0.741667</td>
#       <td id="T_ab1d3_row1_col12" class="data row1 col12" >0.036111</td>
#       <td id="T_ab1d3_row1_col13" class="data row1 col13" >0.332331</td>
#       <td id="T_ab1d3_row1_col14" class="data row1 col14" >0.942912</td>
#       <td id="T_ab1d3_row1_col15" class="data row1 col15" >9.670774</td>
#     </tr>
#     <tr>
#       <th id="T_ab1d3_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_ab1d3_row2_col0" class="data row2 col0" >RandomForestClassifier</td>
#       <td id="T_ab1d3_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_ab1d3_row2_col2" class="data row2 col2" >0.794444</td>
#       <td id="T_ab1d3_row2_col3" class="data row2 col3" >0.044444</td>
#       <td id="T_ab1d3_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_ab1d3_row2_col5" class="data row2 col5" >0.774581</td>
#       <td id="T_ab1d3_row2_col6" class="data row2 col6" >0.015075</td>
#       <td id="T_ab1d3_row2_col7" class="data row2 col7" >1.000000</td>
#       <td id="T_ab1d3_row2_col8" class="data row2 col8" >0.798976</td>
#       <td id="T_a

# %%
explainer = shap.TreeExplainer(best_model_slow)
shap_values_slow = explainer.shap_values(X_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_slow, axis=2)], 
                          X_test, title="Feature Importance Using SHAP Values (Cooking Simulator)",
                          class_names=['Cooking Simulator'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
# Find the participant with the highest misclassification
misclassified_participant = np.argmax(np.sum(cm_slow, axis=1) - np.diag(cm_slow))
confused_with = np.argmax(cm_slow[misclassified_participant, :])
print(f"Participant {misclassified_participant} is most often misclassified as {confused_with}")
# Out:
# Participant 22 is most often misclassified as 13

# %%
# Compare features between the misclassified participant and the one they're confused with
features_to_compare = [col for col in mov_slow.columns if col != 'ID']
misclassified_data = mov_slow[mov_slow['ID'] == misclassified_participant][features_to_compare]
confused_with_data = mov_slow[mov_slow['ID'] == confused_with][features_to_compare]

# %%
# Calculate feature similarities
similarities = 1 - np.abs(misclassified_data.mean() - confused_with_data.mean()) / (misclassified_data.mean() + confused_with_data.mean())

# Sort features by similarity
most_similar_features = similarities.sort_values(ascending=False)

# %%
print("\nTop 10 most similar features:")
print(most_similar_features.head(10))
# Out:
# Top 10 most similar features:
# time_interval                  1.000000
# Head_OrientationAccelY_mean    1.000000
# Accel_HeadPosX_mean            1.000000
# Accel_LeftTouchPosX_mean       0.999999
# Accel_HeadPosX_min             0.999999
# Head_OrientationAccelZ_mean    0.999997
# Head_OrientationAccelX_mean    0.999997
# Accel_LeftTouchPosZ_mean       0.999996
# Accel_HeadPosZ_min             0.999996
# Accel_RightTouchPosX_mean      0.999993
# dtype: float64

# %%
# Visualize feature distributions for top 5 similar features
top_5_features = most_similar_features.head(5).index

fig, axes = plt.subplots(5, 1, figsize=(24, 40))
for i, feature in enumerate(top_5_features):
    sns.kdeplot(data=misclassified_data[feature], ax=axes[i], label=f"Participant {misclassified_participant}")
    sns.kdeplot(data=confused_with_data[feature], ax=axes[i], label=f"Participant {confused_with}")
    axes[i].set_title(feature)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
# Analyze differences in other features
differences = np.abs(misclassified_data.mean() - confused_with_data.mean()) / (misclassified_data.mean() + confused_with_data.mean())
most_different_features = differences.sort_values(ascending=False)

print("\nTop 10 most different features:")
print(most_different_features.head(10))
# Out:
# Top 10 most different features:
# HeadOrientationW_min                0.939602
# HeadOrientationW_25%                0.902683
# HeadOrientationW_50%                0.872007
# LeftTouch_OrientationAccelY_max     0.867718
# HeadOrientationW_mean               0.863951
# HeadOrientationW_75%                0.840295
# LeftTouch_OrientationAccelX_max     0.829309
# RightTouch_OrientationAccelX_max    0.790159
# HeadOrientationW_max                0.763230
# LeftTouch_OrientationAccelZ_max     0.754753
# dtype: float64

# %%
# Visualize feature distributions for top 5 different features
top_5_different_features = most_different_features.head(5).index

fig, axes = plt.subplots(5, 1, figsize=(24, 40))
for i, feature in enumerate(top_5_different_features):
    sns.kdeplot(data=misclassified_data[feature], ax=axes[i], label=f"Participant {misclassified_participant}")
    sns.kdeplot(data=confused_with_data[feature], ax=axes[i], label=f"Participant {confused_with}")
    axes[i].set_title(feature)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
evaluator.plot_accuracy_by_vote(best_model_slow, X_test, y_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10         0.766667
# 1                      20         0.766667
# 2                      30         0.833333
# 3                      40         0.833333
# 4                      50         0.866667
# 5                      60         0.866667
# 6                      70         0.866667
# 7                      80         0.933333
# 8                      90         0.900000
# 9                     100         0.900000
# 10                    110         0.900000
# 11                    120         0.900000

# %%
evaluator.accuracy_over_time(X, y,best_model_slow_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.288889            0.058333
# 1                      120            0.422222            0.036111
# 2                      180            0.525000            0.036111
# 3                      240            0.608333            0.038889
# 4                      300            0.638889            0.041667
# 5                      360            0.680556            0.036111
# 6                      420            0.713889            0.052778
# 7                      480            0.811111            0.041667

# %%
evaluator.accuracy_over_ids(X_train, y_train, best_model_slow_name,  X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            0.966667            0.200000
# 1                             10            0.950000            0.033333
# 2                             15            0.955556            0.133333
# 3                             20            0.875000            0.095833
# 4                             25            0.800000            0.086667
# 5                             30            0.811111            0.041667

# %% [markdown]
# ### 2.2. Training On Beat Saber

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast,  best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(fX_train,fy_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Fast)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:19<00:05,  5.54s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:36<00:00,  6.10s/it]
# <style type="text/css">
# #T_ea5b8_row0_col1, #T_ea5b8_row0_col4, #T_ea5b8_row0_col7, #T_ea5b8_row0_col10, #T_ea5b8_row0_col14, #T_ea5b8_row0_col15, #T_ea5b8_row1_col1, #T_ea5b8_row1_col2, #T_ea5b8_row1_col4, #T_ea5b8_row1_col7, #T_ea5b8_row1_col8, #T_ea5b8_row1_col10, #T_ea5b8_row1_col11, #T_ea5b8_row2_col13, #T_ea5b8_row3_col1, #T_ea5b8_row3_col4, #T_ea5b8_row3_col5, #T_ea5b8_row3_col7, #T_ea5b8_row3_col10, #T_ea5b8_row4_col1, #T_ea5b8_row4_col2, #T_ea5b8_row4_col4, #T_ea5b8_row4_col7, #T_ea5b8_row4_col10, #T_ea5b8_row4_col11, #T_ea5b8_row5_col1, #T_ea5b8_row5_col3, #T_ea5b8_row5_col4, #T_ea5b8_row5_col6, #T_ea5b8_row5_col7, #T_ea5b8_row5_col9, #T_ea5b8_row5_col10, #T_ea5b8_row5_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ea5b8_row0_col2, #T_ea5b8_row0_col3, #T_ea5b8_row0_col6, #T_ea5b8_row0_col9, #T_ea5b8_row0_col11, #T_ea5b8_row0_col12, #T_ea5b8_row0_col13, #T_ea5b8_row2_col1, #T_ea5b8_row2_col4, #T_ea5b8_row2_col5, #T_ea5b8_row2_col7, #T_ea5b8_row2_col8, #T_ea5b8_row2_col10, #T_ea5b8_row3_col13, #T_ea5b8_row4_col13, #T_ea5b8_row4_col15, #T_ea5b8_row5_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ea5b8_row0_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_ea5b8_row0_col8 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_ea5b8_row1_col3, #T_ea5b8_row1_col6, #T_ea5b8_row1_col12 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_ea5b8_row1_col5, #T_ea5b8_row4_col9 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_ea5b8_row1_col9 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_ea5b8_row1_col13 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_ea5b8_row1_col14 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_ea5b8_row1_col15, #T_ea5b8_row3_col15, #T_ea5b8_row5_col15 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ea5b8_row2_col2, #T_ea5b8_row2_col11, #T_ea5b8_row5_col2, #T_ea5b8_row5_col11 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_ea5b8_row2_col3, #T_ea5b8_row2_col6, #T_ea5b8_row2_col12 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_ea5b8_row2_col9 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_ea5b8_row2_col14 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_ea5b8_row2_col15 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ea5b8_row3_col2, #T_ea5b8_row3_col11 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_ea5b8_row3_col3, #T_ea5b8_row3_col12 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_ea5b8_row3_col6 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_ea5b8_row3_col8 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_ea5b8_row3_col9 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_ea5b8_row3_col14 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ea5b8_row4_col3, #T_ea5b8_row4_col6, #T_ea5b8_row4_col12 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_ea5b8_row4_col5 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_ea5b8_row4_col8 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_ea5b8_row4_col14 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_ea5b8_row5_col5 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_ea5b8_row5_col8 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_ea5b8_row5_col13 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# </style>
# <table id="T_ea5b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea5b8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea5b8_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_ea5b8_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_ea5b8_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_ea5b8_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_ea5b8_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_ea5b8_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_ea5b8_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_ea5b8_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_ea5b8_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_ea5b8_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_ea5b8_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_ea5b8_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_ea5b8_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_ea5b8_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_ea5b8_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea5b8_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ea5b8_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_ea5b8_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_ea5b8_row0_col2" class="data row0 col2" >0.030556</td>
#       <td id="T_ea5b8_row0_col3" class="data row0 col3" >0.069444</td>
#       <td id="T_ea5b8_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_ea5b8_row0_col5" class="data row0 col5" >0.026350</td>
#       <td id="T_ea5b8_row0_col6" class="data row0 col6" >0.069178</td>
#       <td id="T_ea5b8_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_ea5b8_row0_col8" class="data row0 col8" >0.023844</td>
#       <td id="T_ea5b8_row0_col9" class="data row0 col9" >0.080788</td>
#       <td id="T_ea5b8_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_ea5b8_row0_col11" class="data row0 col11" >0.030556</td>
#       <td id="T_ea5b8_row0_col12" class="data row0 col12" >0.069444</td>
#       <td id="T_ea5b8_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_ea5b8_row0_col14" class="data row0 col14" >34.942320</td>
#       <td id="T_ea5b8_row0_col15" class="data row0 col15" >33.540622</td>
#     </tr>
#     <tr>
#       <th id="T_ea5b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea5b8_row1_col0" class="data row1 col0" >RandomForestClassifier</td>
#       <td id="T_ea5b8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ea5b8_row1_col2" class="data row1 col2" >0.050000</td>
#       <td id="T_ea5b8_row1_col3" class="data row1 col3" >0.886111</td>
#       <td id="T_ea5b8_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_ea5b8_row1_col5" class="data row1 col5" >0.052650</td>
#       <td id="T_ea5b8_row1_col6" class="data row1 col6" >0.883692</td>
#       <td id="T_ea5b8_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_ea5b8_row1_col8" class="data row1 col8" >0.098408</td>
#       <td id="T_ea5b8_row1_col9" class="data row1 col9" >0.902768</td>
#       <td id="T_ea5b8_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_ea5b8_row1_col11" class="data row1 col11" >0.050000</td>
#       <td id="T_ea5b8_row1_col12" class="data row1 col12" >0.886111</td>
#       <td id="T_ea5b8_row1_col13" class="data row1 col13" >0.146466</td>
#       <td id="T_ea5b8_row1_col14" class="data row1 col14" >11.496360</td>
#       <td id="T_ea5b8_row1_col15" class="data row1 col15" >0.672488</td>
#     </tr>
#     <tr>
#       <th id="T_ea5b8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ea5b8_row2_col0" class="data row2 col0" >LogisticRegression</td>
#       <td id="T_ea5b8_row2_col1" class="data row2 col1" >0.989583</td>
#       <td id="T_ea5b8_row2_col2" class="data row2 col2" >0.033333</td>
#       <td id="T_ea5b8_row2_col3" class="data row2 col3" >0.894444</td>
#       <td id="T_ea5b8_row2_col4" class="data row2 col4" >0.989541</td>
#       <td id="T_ea5b8_row2_col5" class="data row2 col5" >0.018804</td>
#       <td id="T_ea5b8_row2_col6" class="data row2 col6" >0.893036</td>
#       <td id="T_ea5b8_row2_col7" class="data row2 col7" >0.989904</td>
#       <td id="T_ea5b8_row2_col8" clas

# %%
explainer = shap.TreeExplainer(best_model_fast)
shap_values_fast = explainer.shap_values(fX_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_fast, axis=2)], 
                          fX_test, title="Feature Importance Using SHAP Values (Beat Saber)",
                          class_names=['Beat Saber'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
evaluator.plot_accuracy_by_vote(best_model_fast, fX_test, fy_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10         0.966667
# 1                      20         0.966667
# 2                      30         1.000000
# 3                      40         1.000000
# 4                      50         1.000000
# 5                      60         1.000000
# 6                      70         1.000000
# 7                      80         1.000000
# 8                      90         1.000000
# 9                     100         1.000000
# 10                    110         1.000000
# 11                    120         1.000000

# %%
evaluator.accuracy_over_time(fX, fy, best_model_fast_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.036111            0.505556
# 1                      120            0.027778            0.627778
# 2                      180            0.044444            0.713889
# 3                      240            0.044444            0.725000
# 4                      300            0.038889            0.744444
# 5                      360            0.050000            0.755556
# 6                      420            0.038889            0.841667
# 7                      480            0.050000            0.930556

# %%
evaluator.accuracy_over_ids(fX_train, fy_train, best_model_fast_name, X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            0.066667            1.000000
# 1                             10            0.100000            1.000000
# 2                             15            0.111111            0.961111
# 3                             20            0.137500            0.933333
# 4                             25            0.020000            0.920000
# 5                             30            0.050000            0.930556

# %% [markdown]
# ### 2.3. Training On Forklift Simulator

# %%
X, y, fX, fy, X_train, y_train, X_test, y_test, fX_train, fy_train, fX_test, fy_test = evaluator.split_data(mov_slow, mov_fast, id_range=range(30,60), train_minutes=8, test_minutes=2)
# Out:
# Size of the training set:  (1440, 462)
# Size of the slow testing set:  (360, 462)
# Size of the fast training set:  (1440, 462)
# Size of the fast testing set:  (360, 462)

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast, best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(X_train,y_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Slow)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:18<00:05,  5.31s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:34<00:00,  5.81s/it]
# <style type="text/css">
# #T_24826_row0_col1, #T_24826_row0_col4, #T_24826_row0_col7, #T_24826_row0_col9, #T_24826_row0_col10, #T_24826_row0_col14, #T_24826_row0_col15, #T_24826_row1_col1, #T_24826_row1_col4, #T_24826_row1_col7, #T_24826_row1_col10, #T_24826_row2_col13, #T_24826_row3_col1, #T_24826_row3_col4, #T_24826_row3_col7, #T_24826_row3_col10, #T_24826_row4_col1, #T_24826_row4_col3, #T_24826_row4_col4, #T_24826_row4_col6, #T_24826_row4_col7, #T_24826_row4_col10, #T_24826_row4_col12, #T_24826_row5_col1, #T_24826_row5_col2, #T_24826_row5_col4, #T_24826_row5_col5, #T_24826_row5_col7, #T_24826_row5_col8, #T_24826_row5_col10, #T_24826_row5_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_24826_row0_col2, #T_24826_row0_col5, #T_24826_row0_col8, #T_24826_row0_col11, #T_24826_row0_col13, #T_24826_row1_col3, #T_24826_row1_col6, #T_24826_row1_col9, #T_24826_row1_col12, #T_24826_row1_col13, #T_24826_row1_col14, #T_24826_row2_col1, #T_24826_row2_col4, #T_24826_row2_col7, #T_24826_row2_col10, #T_24826_row3_col14, #T_24826_row4_col15, #T_24826_row5_col13, #T_24826_row5_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_24826_row0_col3, #T_24826_row0_col12 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_24826_row0_col6 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_24826_row1_col2, #T_24826_row1_col11 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_24826_row1_col5, #T_24826_row2_col2, #T_24826_row2_col5, #T_24826_row2_col11 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_24826_row1_col8 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_24826_row1_col15 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_24826_row2_col3, #T_24826_row2_col12 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_24826_row2_col6 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_24826_row2_col8 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_24826_row2_col9 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_24826_row2_col14, #T_24826_row4_col14 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_24826_row2_col15 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_24826_row3_col2, #T_24826_row3_col11 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_24826_row3_col3, #T_24826_row3_col12 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_24826_row3_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_24826_row3_col6 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_24826_row3_col8, #T_24826_row4_col2, #T_24826_row4_col5, #T_24826_row4_col11 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_24826_row3_col9 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_24826_row3_col13 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_24826_row3_col15 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_24826_row4_col8 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_24826_row4_col9 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_24826_row4_col13 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_24826_row5_col3, #T_24826_row5_col12 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_24826_row5_col6 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_24826_row5_col9 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_24826_row5_col15 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# </style>
# <table id="T_24826">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24826_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_24826_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_24826_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_24826_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_24826_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_24826_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_24826_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_24826_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_24826_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_24826_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_24826_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_24826_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_24826_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_24826_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_24826_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_24826_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24826_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_24826_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_24826_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_24826_row0_col2" class="data row0 col2" >0.144444</td>
#       <td id="T_24826_row0_col3" class="data row0 col3" >0.036111</td>
#       <td id="T_24826_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_24826_row0_col5" class="data row0 col5" >0.143723</td>
#       <td id="T_24826_row0_col6" class="data row0 col6" >0.034797</td>
#       <td id="T_24826_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_24826_row0_col8" class="data row0 col8" >0.170525</td>
#       <td id="T_24826_row0_col9" class="data row0 col9" >0.046995</td>
#       <td id="T_24826_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_24826_row0_col11" class="data row0 col11" >0.144444</td>
#       <td id="T_24826_row0_col12" class="data row0 col12" >0.036111</td>
#       <td id="T_24826_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_24826_row0_col14" class="data row0 col14" >30.837348</td>
#       <td id="T_24826_row0_col15" class="data row0 col15" >34.742077</td>
#     </tr>
#     <tr>
#       <th id="T_24826_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_24826_row1_col0" class="data row1 col0" >LGBMClassifier</td>
#       <td id="T_24826_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_24826_row1_col2" class="data row1 col2" >0.947222</td>
#       <td id="T_24826_row1_col3" class="data row1 col3" >0.033333</td>
#       <td id="T_24826_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_24826_row1_col5" class="data row1 col5" >0.947464</td>
#       <td id="T_24826_row1_col6" class="data row1 col6" >0.011821</td>
#       <td id="T_24826_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_24826_row1_col8" class="data row1 col8" >0.954750</td>
#       <td id="T_24826_row1_col9" class="data row1 col9" >0.007207</td>
#       <td id="T_24826_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_24826_row1_col11" class="data row1 col11" >0.947222</td>
#       <td id="T_24826_row1_col12" class="data row1 col12" >0.033333</td>
#       <td id="T_24826_row1_col13" class="data row1 col13" >0.000018</td>
#       <td id="T_24826_row1_col14" class="data row1 col14" >0.235997</td>
#       <td id="T_24826_row1_col15" class="data row1 col15" >11.470965</td>
#     </tr>
#     <tr>
#       <th id="T_24826_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_24826_row2_col0" class="data row2 col0" >LogisticRegression</td>
#       <td id="T_24826_row2_col1" class="data row2 col1" >0.977083</td>
#       <td id="T_24826_row2_col2" class="data row2 col2" >0.950000</td>
#       <td id="T_24826_row2_col3" class="data row2 col3" >0.055556</td>
#       <td id="T_24826_row2_col4" class="data row2 col4" >0.977070</td>
#       <td id="T_24826_row2_col5" class="data row2 col5" >0.950272</td>
#       <td id="T_24826_row2_col6" class="data row2 col6" >0.017631</td>
#       <td id="T_24826_row2_col7" class="data row2 col7" >0.977970<

# %%
explainer = shap.TreeExplainer(best_model_slow)
shap_values_slow = explainer.shap_values(X_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_slow, axis=2)], 
                          X_test, title="Feature Importance Using SHAP Values (ForkLift Simulator)",
                          class_names=['ForkLift Simulator'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
evaluator.plot_accuracy_by_vote(best_model_slow, X_test, y_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10              1.0
# 1                      20              1.0
# 2                      30              1.0
# 3                      40              1.0
# 4                      50              1.0
# 5                      60              1.0
# 6                      70              1.0
# 7                      80              1.0
# 8                      90              1.0
# 9                     100              1.0
# 10                    110              1.0
# 11                    120              1.0

# %%
evaluator.accuracy_over_time(X, y,best_model_slow_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.808333            0.050000
# 1                      120            0.911111            0.058333
# 2                      180            0.963889            0.061111
# 3                      240            0.972222            0.058333
# 4                      300            0.986111            0.061111
# 5                      360            0.991667            0.061111
# 6                      420            0.991667            0.066667
# 7                      480            0.997222            0.058333

# %%
evaluator.accuracy_over_ids(X_train, y_train,best_model_slow_name, X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            1.000000            0.383333
# 1                             10            0.991667            0.150000
# 2                             15            0.994444            0.161111
# 3                             20            0.995833            0.095833
# 4                             25            0.993333            0.083333
# 5                             30            0.997222            0.058333

# %% [markdown]
# ### 2.4. Training On Medal of Honor

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast, best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(fX_train,fy_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Fast)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
# 100%|██████████| 15/15 [06:51<00:00, 27.42s/it]
# <style type="text/css">
# #T_56d82_row0_col1, #T_56d82_row0_col10 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_56d82_row0_col2, #T_56d82_row0_col3, #T_56d82_row0_col5, #T_56d82_row0_col6, #T_56d82_row0_col8, #T_56d82_row0_col9, #T_56d82_row0_col11, #T_56d82_row0_col12, #T_56d82_row1_col13, #T_56d82_row2_col1, #T_56d82_row2_col4, #T_56d82_row2_col7, #T_56d82_row2_col10, #T_56d82_row3_col14, #T_56d82_row4_col13, #T_56d82_row10_col13, #T_56d82_row11_col15, #T_56d82_row12_col13, #T_56d82_row12_col15, #T_56d82_row13_col15, #T_56d82_row14_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_56d82_row0_col4, #T_56d82_row2_col3, #T_56d82_row2_col12, #T_56d82_row3_col15, #T_56d82_row7_col13 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_56d82_row0_col7, #T_56d82_row5_col6 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_56d82_row0_col13 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_56d82_row0_col14, #T_56d82_row8_col13 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_56d82_row0_col15, #T_56d82_row2_col14 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_56d82_row1_col1, #T_56d82_row1_col4, #T_56d82_row1_col7, #T_56d82_row1_col10, #T_56d82_row1_col14, #T_56d82_row1_col15, #T_56d82_row4_col1, #T_56d82_row4_col4, #T_56d82_row4_col7, #T_56d82_row4_col10, #T_56d82_row5_col13, #T_56d82_row6_col1, #T_56d82_row6_col4, #T_56d82_row6_col7, #T_56d82_row6_col10, #T_56d82_row8_col1, #T_56d82_row8_col2, #T_56d82_row8_col4, #T_56d82_row8_col7, #T_56d82_row8_col10, #T_56d82_row8_col11, #T_56d82_row10_col1, #T_56d82_row10_col4, #T_56d82_row10_col5, #T_56d82_row10_col7, #T_56d82_row10_col8, #T_56d82_row10_col10, #T_56d82_row12_col1, #T_56d82_row12_col4, #T_56d82_row12_col7, #T_56d82_row12_col10, #T_56d82_row13_col1, #T_56d82_row13_col4, #T_56d82_row13_col5, #T_56d82_row13_col7, #T_56d82_row13_col10, #T_56d82_row14_col1, #T_56d82_row14_col3, #T_56d82_row14_col4, #T_56d82_row14_col6, #T_56d82_row14_col7, #T_56d82_row14_col9, #T_56d82_row14_col10, #T_56d82_row14_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_56d82_row1_col2, #T_56d82_row1_col11, #T_56d82_row2_col2, #T_56d82_row2_col11 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_56d82_row1_col3, #T_56d82_row1_col12, #T_56d82_row13_col14 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_56d82_row1_col5 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_56d82_row1_col6, #T_56d82_row2_col15, #T_56d82_row11_col14, #T_56d82_row12_col14, #T_56d82_row14_col15 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_56d82_row1_col8 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_56d82_row1_col9, #T_56d82_row5_col8, #T_56d82_row11_col13 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_56d82_row2_col5 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_56d82_row2_col6 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_56d82_row2_col8 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_56d82_row2_col9, #T_56d82_row9_col15, #T_56d82_row10_col15 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_56d82_row2_col13 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_56d82_row3_col1, #T_56d82_row3_col4, #T_56d82_row3_col10 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_56d82_row3_col2, #T_56d82_row3_col11, #T_56d82_row4_col9 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_56d82_row3_col3, #T_56d82_row3_col12 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_56d82_row3_col5, #T_56d82_row4_col15 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_56d82_row3_col6 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_56d82_row3_col7 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_56d82_row3_col8, #T_56d82_row11_col9, #T_56d82_row12_col9 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_56d82_row3_col9 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_56d82_row3_col13 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_56d82_row4_col2, #T_56d82_row4_col11 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_56d82_row4_col3, #T_56d82_row4_col12 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_56d82_row4_col5 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_56d82_row4_col6 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_56d82_row4_col8 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_56d82_row4_col14 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col1, #T_56d82_row5_col10, #T_56d82_row8_col6 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col2, #T_56d82_row5_col11 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_56d82_row5_col3, #T_56d82_row5_col12 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col4, #T_56d82_row6_col14 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col5 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_56d82_row5_col7 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col9 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col14, #T_56d82_row9_col1, #T_56d82_row9_col4, #T_56d82_row9_col7, #T_56d82_row9_col10 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_56d82_row5_col15, #T_56d82_row14_col8 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_56d82_row6_col2, #T_56d82_row6_col11 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_56d82_row6_col3, #T_56d82_row6_col6, #T_56d82_row6_col12, #T_56d82_row7_col9 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_56d82_row6_col5, #T_56d82_row7_col7 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_56d82_row6_col8, #T_56d82_row7_col6 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_56d82_row6_col9 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_56d82_row6_col13, #T_56d82_row8_col15, #T_56d82_row9_col13 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_56d82_row6_col15 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_56d82_row7_col1, #T_56d82_row7_col10 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_56d82_row7_col2, #T_56d82_row7_col11 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_56d82_row7_col3, #T_56d82_row7_col12 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_56d82_row7_col4, #T_56d82_row13_col9 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_56d82_row7_col5 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_56d82_row7_col8 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_56d82_row7_col14 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_56d82_row7_col15 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_56d82_row8_col3, #T_56d82_row8_col12 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_56d82_row8_col5 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_56d82_row8_col8 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_56d82_row8_col9 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_56d82_row8_col14 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_56d82_row9_col2, #T_56d82_row9_col11 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_56d82_row9_col3, #T_56d82_row9_col6, #T_56d82_row9_col12, #T_56d82_row10_col3, #T_56d82_row10_col12 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_56d82_row9_col5, #T_56d82_row13_col6 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_56d82_row9_col8, #T_56d82_row10_col9 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_56d82_row9_col9, #T_56d82_row10_col2, #T_56d82_row10_col11, #T_56d82_row11_col2, #T_56d82_row11_col11 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_56d82_row9_col14 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_56d82_row10_col6 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_56d82_row10_col14 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_56d82_row11_col1, #T_56d82_row11_col4, #T_56d82_row11_col7, #T_56d82_row11_col10 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_56d82_row11_col3, #T_56d82_row11_col6, #T_56d82_row11_col12, #T_56d82_row12_col6 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_56d82_row11_col5 {
#   background-color: #0e5

# %%
explainer = shap.TreeExplainer(best_model_fast)
shap_values_fast = explainer.shap_values(fX_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_fast, axis=2)], 
                          fX_test, title="Feature Importance Using SHAP Values (Medal Of Honor)",
                          class_names=['Medal Of Honor'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
evaluator.plot_accuracy_by_vote(best_model_fast, fX_test, fy_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10         0.866667
# 1                      20         0.866667
# 2                      30         0.766667
# 3                      40         0.700000
# 4                      50         0.733333
# 5                      60         0.733333
# 6                      70         0.766667
# 7                      80         0.800000
# 8                      90         0.800000
# 9                     100         0.800000
# 10                    110         0.800000
# 11                    120         0.866667

# %%
evaluator.accuracy_over_time(fX, fy,best_model_fast_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.102778            0.319444
# 1                      120            0.119444            0.366667
# 2                      180            0.077778            0.419444
# 3                      240            0.094444            0.461111
# 4                      300            0.122222            0.522222
# 5                      360            0.150000            0.536111
# 6                      420            0.136111            0.588889
# 7                      480            0.136111            0.669444

# %%
evaluator.accuracy_over_ids(fX_train, fy_train,best_model_fast_name, X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            0.400000            0.933333
# 1                             10            0.233333            0.850000
# 2                             15            0.255556            0.750000
# 3                             20            0.212500            0.675000
# 4                             25            0.170000            0.670000
# 5                             30            0.136111            0.669444

# %% [markdown]
# # 3. Identification based on user movements and traffic

# %%
# import numpy for math calculations
import numpy as np

# import pandas for data (csv) manipulation
import pandas as pd

# import matplotlib for plotting
import matplotlib.pyplot as plt

import sys  
sys.path.insert(1, '../src/')

from train_model import ClassifierEvaluator
from visualize import VisualizationUtils
import seaborn as sns
# import shap for ai explainability
import shap

from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn import tree

# import warnings to hide the unnessairy warniings
import warnings
warnings.filterwarnings('ignore')

# %%
mov_slow = pd.read_csv('../data/processed/movement_slow_stat_cleaned.csv').drop(columns=['Unnamed: 0']).fillna(0)
mov_fast = pd.read_csv('../data/processed/movement_fast_stat_cleaned.csv').drop(columns=['Unnamed: 0']).fillna(0)
traffic_slow = pd.read_csv('../data/processed/traffic_slow_stat_cleaned.csv', index_col=0).fillna(0)
traffic_fast = pd.read_csv('../data/processed/traffic_fast_stat_cleaned.csv', index_col=0).fillna(0)

# Concatenate movement and traffic data for both slow and fast datasets
slow_combined = pd.concat([mov_slow, traffic_slow.drop(columns=['time_interval','ID'])], axis=1).dropna()
fast_combined = pd.concat([mov_fast, traffic_fast.drop(columns=['time_interval','ID'])], axis=1).dropna()
unique_minutes = list(range(1,11))

# %% [markdown]
# ### 3.1. Training On Cooking Similator

# %%
evaluator = ClassifierEvaluator()
X, y, fX, fy, X_train, y_train, X_test, y_test, fX_train, fy_train, fX_test, fy_test = evaluator.split_data(slow_combined, fast_combined, id_range=range(0,30), train_minutes=8, test_minutes=2)
# Out:
# Size of the training set:  (1437, 490)
# Size of the slow testing set:  (360, 490)
# Size of the fast training set:  (1440, 490)
# Size of the fast testing set:  (360, 490)

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast, best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(X_train,y_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Slow)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:21<00:06,  6.51s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:42<00:00,  7.15s/it]
# <style type="text/css">
# #T_7f31d_row0_col1, #T_7f31d_row0_col4, #T_7f31d_row0_col7, #T_7f31d_row0_col10, #T_7f31d_row0_col14, #T_7f31d_row0_col15, #T_7f31d_row1_col13, #T_7f31d_row2_col1, #T_7f31d_row2_col3, #T_7f31d_row2_col4, #T_7f31d_row2_col6, #T_7f31d_row2_col7, #T_7f31d_row2_col9, #T_7f31d_row2_col10, #T_7f31d_row2_col12, #T_7f31d_row3_col1, #T_7f31d_row3_col4, #T_7f31d_row3_col7, #T_7f31d_row3_col10, #T_7f31d_row4_col1, #T_7f31d_row4_col4, #T_7f31d_row4_col7, #T_7f31d_row4_col10, #T_7f31d_row5_col1, #T_7f31d_row5_col2, #T_7f31d_row5_col4, #T_7f31d_row5_col5, #T_7f31d_row5_col7, #T_7f31d_row5_col8, #T_7f31d_row5_col10, #T_7f31d_row5_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7f31d_row0_col2, #T_7f31d_row0_col3, #T_7f31d_row0_col5, #T_7f31d_row0_col6, #T_7f31d_row0_col8, #T_7f31d_row0_col9, #T_7f31d_row0_col11, #T_7f31d_row0_col12, #T_7f31d_row0_col13, #T_7f31d_row1_col1, #T_7f31d_row1_col4, #T_7f31d_row1_col7, #T_7f31d_row1_col10, #T_7f31d_row2_col13, #T_7f31d_row2_col14, #T_7f31d_row3_col15, #T_7f31d_row4_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7f31d_row1_col2, #T_7f31d_row1_col11 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_7f31d_row1_col3, #T_7f31d_row1_col12 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_7f31d_row1_col5 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_7f31d_row1_col6 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_7f31d_row1_col8 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_7f31d_row1_col9 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_7f31d_row1_col14, #T_7f31d_row5_col14 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7f31d_row1_col15 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_7f31d_row2_col2, #T_7f31d_row2_col11 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_7f31d_row2_col5 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_7f31d_row2_col8 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_7f31d_row2_col15 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7f31d_row3_col2, #T_7f31d_row3_col5, #T_7f31d_row3_col11 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_7f31d_row3_col3, #T_7f31d_row3_col12, #T_7f31d_row5_col3, #T_7f31d_row5_col12 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_7f31d_row3_col6 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_7f31d_row3_col8 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_7f31d_row3_col9 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_7f31d_row3_col13 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_7f31d_row3_col14, #T_7f31d_row4_col14 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7f31d_row4_col2, #T_7f31d_row4_col11 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_7f31d_row4_col3, #T_7f31d_row4_col12 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_7f31d_row4_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_7f31d_row4_col6 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_7f31d_row4_col8 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_7f31d_row4_col9 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_7f31d_row4_col15 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7f31d_row5_col6 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_7f31d_row5_col9 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_7f31d_row5_col13 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_7f31d_row5_col15 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# </style>
# <table id="T_7f31d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f31d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f31d_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_7f31d_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_7f31d_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_7f31d_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_7f31d_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_7f31d_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_7f31d_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_7f31d_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_7f31d_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_7f31d_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_7f31d_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_7f31d_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_7f31d_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_7f31d_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_7f31d_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f31d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_7f31d_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_7f31d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_7f31d_row0_col2" class="data row0 col2" >0.097222</td>
#       <td id="T_7f31d_row0_col3" class="data row0 col3" >0.047222</td>
#       <td id="T_7f31d_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_7f31d_row0_col5" class="data row0 col5" >0.100001</td>
#       <td id="T_7f31d_row0_col6" class="data row0 col6" >0.041828</td>
#       <td id="T_7f31d_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_7f31d_row0_col8" class="data row0 col8" >0.116633</td>
#       <td id="T_7f31d_row0_col9" class="data row0 col9" >0.039539</td>
#       <td id="T_7f31d_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_7f31d_row0_col11" class="data row0 col11" >0.097222</td>
#       <td id="T_7f31d_row0_col12" class="data row0 col12" >0.047222</td>
#       <td id="T_7f31d_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_7f31d_row0_col14" class="data row0 col14" >32.539409</td>
#       <td id="T_7f31d_row0_col15" class="data row0 col15" >34.341592</td>
#     </tr>
#     <tr>
#       <th id="T_7f31d_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_7f31d_row1_col0" class="data row1 col0" >LogisticRegression</td>
#       <td id="T_7f31d_row1_col1" class="data row1 col1" >0.983994</td>
#       <td id="T_7f31d_row1_col2" class="data row1 col2" >0.802778</td>
#       <td id="T_7f31d_row1_col3" class="data row1 col3" >0.105556</td>
#       <td id="T_7f31d_row1_col4" class="data row1 col4" >0.983929</td>
#       <td id="T_7f31d_row1_col5" class="data row1 col5" >0.790509</td>
#       <td id="T_7f31d_row1_col6" class="data row1 col6" >0.049526</td>
#       <td id="T_7f31d_row1_col7" class="data row1 col7" >0.984351</td>
#       <td id="T_7f31d_row1_col8" class="data row1 col8" >0.798653</td>
#       <td id="T_7f31d_row1_col9" class="data row1 col9" >0.091827</td>
#       <td id="T_7f31d_row1_col10" class="data row1 col10" >0.984028</td>
#       <td id="T_7f31d_row1_col11" class="data row1 col11" >0.802778</td>
#       <td id="T_7f31d_row1_col12" class="data row1 col12" >0.105556</td>
#       <td id="T_7f31d_row1_col13" class="data row1 col13" >0.252338</td>
#       <td id="T_7f31d_row1_col14" class="data row1 col14" >0.714955</td>
#       <td id="T_7f31d_row1_col15" class="data row1 col15" >6.582691</td>
#     </tr>
#     <tr>
#       <th id="T_7f31d_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_7f31d_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_7f31d_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_7f31d_row2_col2" class="data row2 col2" >0.841667</td>
#       <td id="T_7f31d_row2_col3" class="data row2 col3" >0.180556</td>
#       <td id="T_7f31d_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_7f31d_row2_col5" class="data row2 col5" >0.

# %%
explainer = shap.TreeExplainer(best_model_slow)
shap_values_slow = explainer.shap_values(X_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_slow, axis=2)], 
                          X_test, title="Feature Importance Using SHAP Values (Cooking Simulator)",
                          class_names=['Cooking Simulator'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
# Find the participant with the highest misclassification
misclassified_participant = np.argmax(np.sum(cm_slow, axis=1) - np.diag(cm_slow))
confused_with = np.argmax(cm_slow[misclassified_participant, :])
print(f"Participant {misclassified_participant} is most often misclassified as {confused_with}")
# Out:
# Participant 19 is most often misclassified as 6

# %%
# Compare features between the misclassified participant and the one they're confused with
features_to_compare = [col for col in mov_slow.columns if col != 'ID']
misclassified_data = mov_slow[mov_slow['ID'] == misclassified_participant][features_to_compare]
confused_with_data = mov_slow[mov_slow['ID'] == confused_with][features_to_compare]

# %%
# Calculate feature similarities
similarities = 1 - np.abs(misclassified_data.mean() - confused_with_data.mean()) / (misclassified_data.mean() + confused_with_data.mean())

# Sort features by similarity
most_similar_features = similarities.sort_values(ascending=False)

# %%
print("\nTop 10 most similar features:")
print(most_similar_features.head(10))
# Out:
# Top 10 most similar features:
# time_interval                  1.000000
# Accel_LeftTouchPosY_mean       1.000000
# Head_OrientationAccelY_mean    0.999999
# Accel_HeadPosX_mean            0.999998
# Accel_RightTouchPosZ_mean      0.999998
# Accel_HeadPosY_mean            0.999997
# Accel_RightTouchPosX_mean      0.999996
# Accel_HeadPosZ_mean            0.999996
# Accel_LeftTouchPosX_mean       0.999995
# Accel_RightTouchPosY_mean      0.999994
# dtype: float64

# %%
# Visualize feature distributions for top 5 similar features
top_5_features = most_similar_features.head(5).index

fig, axes = plt.subplots(5, 1, figsize=(24, 40))
for i, feature in enumerate(top_5_features):
    sns.kdeplot(data=misclassified_data[feature], ax=axes[i], label=f"Participant {misclassified_participant}")
    sns.kdeplot(data=confused_with_data[feature], ax=axes[i], label=f"Participant {confused_with}")
    axes[i].set_title(feature)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
# Analyze differences in other features
differences = np.abs(misclassified_data.mean() - confused_with_data.mean()) / (misclassified_data.mean() + confused_with_data.mean())
most_different_features = differences.sort_values(ascending=False)

print("\nTop 10 most different features:")
print(most_different_features.head(10))
# Out:
# Top 10 most different features:
# LeftTouch_OrientationAccelY_std        0.950256
# LeftTouch_OrientationAccelY_max        0.943778
# LeftTouch_OrientationVelocityY_max     0.924526
# LeftTouch_OrientationVelocityY_std     0.894665
# RightTouch_OrientationAccelY_max       0.827080
# RightTouch_OrientationAccelY_std       0.816302
# Head_OrientationAccelZ_max             0.804402
# RightTouch_OrientationVelocityY_max    0.762452
# RightTouch_OrientationVelocityY_std    0.736701
# LeftTouchOrientationY_std              0.728629
# dtype: float64

# %%
# Visualize feature distributions for top 5 different features
top_5_different_features = most_different_features.head(5).index

fig, axes = plt.subplots(5, 1, figsize=(24, 40))
for i, feature in enumerate(top_5_different_features):
    sns.kdeplot(data=misclassified_data[feature], ax=axes[i], label=f"Participant {misclassified_participant}")
    sns.kdeplot(data=confused_with_data[feature], ax=axes[i], label=f"Participant {confused_with}")
    axes[i].set_title(feature)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
evaluator.plot_accuracy_by_vote(best_model_slow, X_test, y_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10         0.933333
# 1                      20         0.933333
# 2                      30         0.933333
# 3                      40         0.933333
# 4                      50         0.933333
# 5                      60         0.933333
# 6                      70         0.933333
# 7                      80         0.966667
# 8                      90         0.966667
# 9                     100         0.966667
# 10                    110         0.966667
# 11                    120         0.966667

# %%
evaluator.accuracy_over_time(X, y,best_model_slow_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.427778            0.083333
# 1                      120            0.519444            0.088889
# 2                      180            0.633333            0.144444
# 3                      240            0.641667            0.136111
# 4                      300            0.702778            0.169444
# 5                      360            0.752778            0.172222
# 6                      420            0.791667            0.172222
# 7                      480            0.883333            0.158333

# %%
evaluator.accuracy_over_ids(X_train, y_train, best_model_slow_name,  X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            1.000000            0.200000
# 1                             10            0.991667            0.175000
# 2                             15            0.983333            0.194444
# 3                             20            0.912500            0.158333
# 4                             25            0.866667            0.226667
# 5                             30            0.883333            0.158333

# %% [markdown]
# ### 3.2. Training On Beat Saber

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast,  best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(fX_train,fy_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Fast)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:18<00:05,  5.49s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:36<00:00,  6.12s/it]
# <style type="text/css">
# #T_00849_row0_col1, #T_00849_row0_col4, #T_00849_row0_col7, #T_00849_row0_col10, #T_00849_row0_col14, #T_00849_row0_col15, #T_00849_row1_col13, #T_00849_row2_col1, #T_00849_row2_col4, #T_00849_row2_col7, #T_00849_row2_col10, #T_00849_row3_col1, #T_00849_row3_col3, #T_00849_row3_col4, #T_00849_row3_col6, #T_00849_row3_col7, #T_00849_row3_col9, #T_00849_row3_col10, #T_00849_row3_col12, #T_00849_row4_col1, #T_00849_row4_col2, #T_00849_row4_col3, #T_00849_row4_col4, #T_00849_row4_col5, #T_00849_row4_col6, #T_00849_row4_col7, #T_00849_row4_col8, #T_00849_row4_col9, #T_00849_row4_col10, #T_00849_row4_col11, #T_00849_row4_col12, #T_00849_row5_col1, #T_00849_row5_col3, #T_00849_row5_col4, #T_00849_row5_col6, #T_00849_row5_col7, #T_00849_row5_col9, #T_00849_row5_col10, #T_00849_row5_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_00849_row0_col2, #T_00849_row0_col3, #T_00849_row0_col5, #T_00849_row0_col6, #T_00849_row0_col8, #T_00849_row0_col9, #T_00849_row0_col11, #T_00849_row0_col12, #T_00849_row0_col13, #T_00849_row1_col1, #T_00849_row1_col4, #T_00849_row1_col7, #T_00849_row1_col10, #T_00849_row2_col13, #T_00849_row2_col15, #T_00849_row3_col13, #T_00849_row3_col14, #T_00849_row5_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_00849_row1_col2, #T_00849_row1_col11 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_00849_row1_col3, #T_00849_row1_col12 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_00849_row1_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_00849_row1_col6 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_00849_row1_col8 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_00849_row1_col9, #T_00849_row3_col8 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_00849_row1_col14 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_00849_row1_col15, #T_00849_row3_col15, #T_00849_row4_col15 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_00849_row2_col2, #T_00849_row2_col11 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_00849_row2_col3, #T_00849_row2_col6, #T_00849_row2_col12 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_00849_row2_col5 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_00849_row2_col8 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_00849_row2_col9 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_00849_row2_col14 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_00849_row3_col2, #T_00849_row3_col11 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_00849_row3_col5 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_00849_row4_col13 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_00849_row4_col14 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_00849_row5_col2, #T_00849_row5_col11 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_00849_row5_col5 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_00849_row5_col8 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_00849_row5_col13 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_00849_row5_col15 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# </style>
# <table id="T_00849">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00849_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_00849_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_00849_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_00849_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_00849_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_00849_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_00849_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_00849_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_00849_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_00849_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_00849_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_00849_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_00849_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_00849_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_00849_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_00849_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00849_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_00849_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_00849_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_00849_row0_col2" class="data row0 col2" >0.038889</td>
#       <td id="T_00849_row0_col3" class="data row0 col3" >0.102778</td>
#       <td id="T_00849_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_00849_row0_col5" class="data row0 col5" >0.032276</td>
#       <td id="T_00849_row0_col6" class="data row0 col6" >0.102893</td>
#       <td id="T_00849_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_00849_row0_col8" class="data row0 col8" >0.029771</td>
#       <td id="T_00849_row0_col9" class="data row0 col9" >0.115609</td>
#       <td id="T_00849_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_00849_row0_col11" class="data row0 col11" >0.038889</td>
#       <td id="T_00849_row0_col12" class="data row0 col12" >0.102778</td>
#       <td id="T_00849_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_00849_row0_col14" class="data row0 col14" >34.641956</td>
#       <td id="T_00849_row0_col15" class="data row0 col15" >32.339167</td>
#     </tr>
#     <tr>
#       <th id="T_00849_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_00849_row1_col0" class="data row1 col0" >LogisticRegression</td>
#       <td id="T_00849_row1_col1" class="data row1 col1" >0.992361</td>
#       <td id="T_00849_row1_col2" class="data row1 col2" >0.077778</td>
#       <td id="T_00849_row1_col3" class="data row1 col3" >0.922222</td>
#       <td id="T_00849_row1_col4" class="data row1 col4" >0.992359</td>
#       <td id="T_00849_row1_col5" class="data row1 col5" >0.080960</td>
#       <td id="T_00849_row1_col6" class="data row1 col6" >0.916279</td>
#       <td id="T_00849_row1_col7" class="data row1 col7" >0.992567</td>
#       <td id="T_00849_row1_col8" class="data row1 col8" >0.127859</td>
#       <td id="T_00849_row1_col9" class="data row1 col9" >0.942175</td>
#       <td id="T_00849_row1_col10" class="data row1 col10" >0.992361</td>
#       <td id="T_00849_row1_col11" class="data row1 col11" >0.077778</td>
#       <td id="T_00849_row1_col12" class="data row1 col12" >0.922222</td>
#       <td id="T_00849_row1_col13" class="data row1 col13" >0.199061</td>
#       <td id="T_00849_row1_col14" class="data row1 col14" >4.467999</td>
#       <td id="T_00849_row1_col15" class="data row1 col15" >0.382606</td>
#     </tr>
#     <tr>
#       <th id="T_00849_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_00849_row2_col0" class="data row2 col0" >LGBMClassifier</td>
#       <td id="T_00849_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_00849_row2_col2" class="data row2 col2" >0.175000</td>
#       <td id="T_00849_row2_col3" class="data row2 col3" >0.947222</td>
#       <td id="T_00849_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_00849_row2_col5" class="data row2 col5" >0.140770</td>
#       <td id="T_00849_row2_col6" class="data row2 col6" >0.945604</td>
#       <td id="T_00849_row2_col7" class="data row2 col7" >1.000000</td>
#       <td id="T_00849_row2_col8" class="data row2 col8" >0.128749</td>
#       <td id="T_00849_row2_col9" class="data row2 col9" >0.952745</td>
#       <td id="T_00849_row2_col10" class="data row2 col

# %%
explainer = shap.TreeExplainer(best_model_fast)
shap_values_fast = explainer.shap_values(fX_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_fast, axis=2)], 
                          fX_test, title="Feature Importance Using SHAP Values (Beat Saber)",
                          class_names=['Beat Saber'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
evaluator.plot_accuracy_by_vote(best_model_fast, fX_test, fy_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10              1.0
# 1                      20              1.0
# 2                      30              1.0
# 3                      40              1.0
# 4                      50              1.0
# 5                      60              1.0
# 6                      70              1.0
# 7                      80              1.0
# 8                      90              1.0
# 9                     100              1.0
# 10                    110              1.0
# 11                    120              1.0

# %%
evaluator.accuracy_over_time(fX, fy, best_model_fast_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.097222            0.850000
# 1                      120            0.125000            0.886111
# 2                      180            0.122222            0.880556
# 3                      240            0.127778            0.888889
# 4                      300            0.105556            0.891667
# 5                      360            0.152778            0.891667
# 6                      420            0.213889            0.938889
# 7                      480            0.194444            0.986111

# %%
evaluator.accuracy_over_ids(fX_train, fy_train, best_model_fast_name, X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            0.383333            1.000000
# 1                             10            0.291667            1.000000
# 2                             15            0.288889            0.994444
# 3                             20            0.220833            0.991667
# 4                             25            0.223333            0.990000
# 5                             30            0.194444            0.986111

# %% [markdown]
# ### 3.3. Training On Forklift Simulator

# %%
X, y, fX, fy, X_train, y_train, X_test, y_test, fX_train, fy_train, fX_test, fy_test = evaluator.split_data(mov_slow, mov_fast, id_range=range(30,60), train_minutes=8, test_minutes=2)
# Out:
# Size of the training set:  (1440, 462)
# Size of the slow testing set:  (360, 462)
# Size of the fast training set:  (1440, 462)
# Size of the fast testing set:  (360, 462)

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast, best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(X_train,y_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Slow)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:17<00:05,  5.09s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:32<00:00,  5.41s/it]
# <style type="text/css">
# #T_94597_row0_col1, #T_94597_row0_col4, #T_94597_row0_col7, #T_94597_row0_col10, #T_94597_row0_col14, #T_94597_row0_col15, #T_94597_row1_col1, #T_94597_row1_col4, #T_94597_row1_col7, #T_94597_row1_col10, #T_94597_row2_col9, #T_94597_row2_col13, #T_94597_row3_col1, #T_94597_row3_col4, #T_94597_row3_col7, #T_94597_row3_col10, #T_94597_row4_col1, #T_94597_row4_col4, #T_94597_row4_col7, #T_94597_row4_col10, #T_94597_row5_col1, #T_94597_row5_col2, #T_94597_row5_col3, #T_94597_row5_col4, #T_94597_row5_col5, #T_94597_row5_col6, #T_94597_row5_col7, #T_94597_row5_col8, #T_94597_row5_col10, #T_94597_row5_col11, #T_94597_row5_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_94597_row0_col2, #T_94597_row0_col5, #T_94597_row0_col8, #T_94597_row0_col11, #T_94597_row0_col13, #T_94597_row1_col6, #T_94597_row1_col9, #T_94597_row1_col13, #T_94597_row1_col14, #T_94597_row2_col1, #T_94597_row2_col4, #T_94597_row2_col7, #T_94597_row2_col10, #T_94597_row3_col14, #T_94597_row4_col3, #T_94597_row4_col12, #T_94597_row4_col15, #T_94597_row5_col13, #T_94597_row5_col14 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_94597_row0_col3, #T_94597_row0_col12 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_94597_row0_col6 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_94597_row0_col9 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_94597_row1_col2, #T_94597_row1_col5, #T_94597_row1_col11 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_94597_row1_col3, #T_94597_row1_col12 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_94597_row1_col8 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_94597_row1_col15 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_94597_row2_col2, #T_94597_row2_col5, #T_94597_row2_col11 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_94597_row2_col3, #T_94597_row2_col12 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_94597_row2_col6 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_94597_row2_col8 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_94597_row2_col14, #T_94597_row4_col14 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_94597_row2_col15 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_94597_row3_col2, #T_94597_row3_col11 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_94597_row3_col3, #T_94597_row3_col12 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_94597_row3_col5 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_94597_row3_col6 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_94597_row3_col8 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_94597_row3_col9 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_94597_row3_col13 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_94597_row3_col15 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_94597_row4_col2, #T_94597_row4_col5, #T_94597_row4_col8, #T_94597_row4_col11 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_94597_row4_col6 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_94597_row4_col9 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_94597_row4_col13 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_94597_row5_col9 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_94597_row5_col15 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_94597">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94597_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_94597_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_94597_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_94597_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_94597_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_94597_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_94597_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_94597_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_94597_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_94597_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_94597_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_94597_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_94597_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_94597_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_94597_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_94597_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94597_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_94597_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_94597_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_94597_row0_col2" class="data row0 col2" >0.133333</td>
#       <td id="T_94597_row0_col3" class="data row0 col3" >0.030556</td>
#       <td id="T_94597_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_94597_row0_col5" class="data row0 col5" >0.135289</td>
#       <td id="T_94597_row0_col6" class="data row0 col6" >0.027233</td>
#       <td id="T_94597_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_94597_row0_col8" class="data row0 col8" >0.171047</td>
#       <td id="T_94597_row0_col9" class="data row0 col9" >0.036040</td>
#       <td id="T_94597_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_94597_row0_col11" class="data row0 col11" >0.133333</td>
#       <td id="T_94597_row0_col12" class="data row0 col12" >0.030556</td>
#       <td id="T_94597_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_94597_row0_col14" class="data row0 col14" >31.237833</td>
#       <td id="T_94597_row0_col15" class="data row0 col15" >34.942320</td>
#     </tr>
#     <tr>
#       <th id="T_94597_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_94597_row1_col0" class="data row1 col0" >LGBMClassifier</td>
#       <td id="T_94597_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_94597_row1_col2" class="data row1 col2" >0.938889</td>
#       <td id="T_94597_row1_col3" class="data row1 col3" >0.033333</td>
#       <td id="T_94597_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_94597_row1_col5" class="data row1 col5" >0.938497</td>
#       <td id="T_94597_row1_col6" class="data row1 col6" >0.012406</td>
#       <td id="T_94597_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_94597_row1_col8" class="data row1 col8" >0.946477</td>
#       <td id="T_94597_row1_col9" class="data row1 col9" >0.007670</td>
#       <td id="T_94597_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_94597_row1_col11" class="data row1 col11" >0.938889</td>
#       <td id="T_94597_row1_col12" class="data row1 col12" >0.033333</td>
#       <td id="T_94597_row1_col13" class="data row1 col13" >0.000018</td>
#       <td id="T_94597_row1_col14" class="data row1 col14" >0.241381</td>
#       <td id="T_94597_row1_col15" class="data row1 col15" >11.560417</td>
#     </tr>
#     <tr>
#       <th id="T_94597_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_94597_row2_col0" class="data row2 col0" >LogisticRegression</td>
#       <td id="T_94597_row2_col1" class="data row2 col1" >0.977083</td>
#       <td id="T_94597_row2_col2" class="data row2 col2" >0.950000</td>
#       <td id="T_94597_row2_col3" class="data row2 col3" >0.052778</td>
#       <td id="T_94597_row2_col4" class="data row2 col4" >0.977070</td>
#       <td id="T_94597_row2_col5" class="data row2 col5" >0.950272</td>
#       <td id="T_94597_row2_col6" class="data row2 col6" >0.027433</td>
#       <td id="T_94597_row2_col7" class="data row2 col7" >0.977970<

# %%
explainer = shap.TreeExplainer(best_model_slow)
shap_values_slow = explainer.shap_values(X_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_slow, axis=2)], 
                          X_test, title="Feature Importance Using SHAP Values (ForkLift Simulator)",
                          class_names=['ForkLift Simulator'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
evaluator.plot_accuracy_by_vote(best_model_slow, X_test, y_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10              1.0
# 1                      20              1.0
# 2                      30              1.0
# 3                      40              1.0
# 4                      50              1.0
# 5                      60              1.0
# 6                      70              1.0
# 7                      80              1.0
# 8                      90              1.0
# 9                     100              1.0
# 10                    110              1.0
# 11                    120              1.0

# %%
evaluator.accuracy_over_time(X, y,best_model_slow_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.808333            0.050000
# 1                      120            0.911111            0.058333
# 2                      180            0.963889            0.061111
# 3                      240            0.972222            0.058333
# 4                      300            0.986111            0.061111
# 5                      360            0.991667            0.061111
# 6                      420            0.991667            0.063889
# 7                      480            0.997222            0.058333

# %%
evaluator.accuracy_over_ids(X_train, y_train,best_model_slow_name, X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            1.000000            0.383333
# 1                             10            0.991667            0.158333
# 2                             15            0.994444            0.161111
# 3                             20            0.995833            0.095833
# 4                             25            0.993333            0.080000
# 5                             30            0.997222            0.058333

# %% [markdown]
# ### 3.4. Training On Medal of Honor

# %%
Accuracy_set, models, best_model_slow, best_model_fast, cm_slow, cm_fast, best_model_slow_name, best_model_fast_name = evaluator.evaluate_classifiers(fX_train,fy_train,X_test,y_test,fX_test,fy_test)
Accuracy_set.sort_values(by='Accuracy(Fast)').style.background_gradient(cmap= plt.cm.Blues)
# Out:
#  83%|██████████████████████████████████████████████████████████▎           | 5/6 [00:18<00:05,  5.41s/it]/home/fede/anaconda3/lib/python3.11/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /home/fede/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████████████████████████████████████████████████████████████████| 6/6 [00:35<00:00,  5.94s/it]
# <style type="text/css">
# #T_f9413_row0_col1, #T_f9413_row0_col4, #T_f9413_row0_col7, #T_f9413_row0_col10, #T_f9413_row0_col14, #T_f9413_row0_col15, #T_f9413_row1_col13, #T_f9413_row2_col1, #T_f9413_row2_col4, #T_f9413_row2_col5, #T_f9413_row2_col7, #T_f9413_row2_col10, #T_f9413_row3_col1, #T_f9413_row3_col4, #T_f9413_row3_col7, #T_f9413_row3_col10, #T_f9413_row4_col1, #T_f9413_row4_col4, #T_f9413_row4_col7, #T_f9413_row4_col10, #T_f9413_row5_col1, #T_f9413_row5_col2, #T_f9413_row5_col3, #T_f9413_row5_col4, #T_f9413_row5_col6, #T_f9413_row5_col7, #T_f9413_row5_col8, #T_f9413_row5_col9, #T_f9413_row5_col10, #T_f9413_row5_col11, #T_f9413_row5_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f9413_row0_col2, #T_f9413_row0_col3, #T_f9413_row0_col5, #T_f9413_row0_col6, #T_f9413_row0_col9, #T_f9413_row0_col11, #T_f9413_row0_col12, #T_f9413_row0_col13, #T_f9413_row1_col1, #T_f9413_row1_col4, #T_f9413_row1_col7, #T_f9413_row1_col8, #T_f9413_row1_col10, #T_f9413_row2_col13, #T_f9413_row3_col13, #T_f9413_row3_col15, #T_f9413_row4_col15, #T_f9413_row5_col14, #T_f9413_row5_col15 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f9413_row0_col8 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_f9413_row1_col2, #T_f9413_row1_col11, #T_f9413_row3_col3, #T_f9413_row3_col6, #T_f9413_row3_col12 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_f9413_row1_col3, #T_f9413_row1_col12 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_f9413_row1_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_f9413_row1_col6 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_f9413_row1_col9 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_f9413_row1_col14 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f9413_row1_col15, #T_f9413_row2_col15 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f9413_row2_col2, #T_f9413_row2_col11 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_f9413_row2_col3, #T_f9413_row2_col12 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_f9413_row2_col6 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_f9413_row2_col8 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_f9413_row2_col9 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_f9413_row2_col14 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f9413_row3_col2, #T_f9413_row3_col11 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_f9413_row3_col5 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_f9413_row3_col8 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_f9413_row3_col9, #T_f9413_row4_col3, #T_f9413_row4_col12 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_f9413_row3_col14 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_f9413_row4_col2, #T_f9413_row4_col11 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_f9413_row4_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_f9413_row4_col6 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_f9413_row4_col8 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_f9413_row4_col9 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_f9413_row4_col13 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_f9413_row4_col14 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_f9413_row5_col5 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_f9413_row5_col13 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# </style>
# <table id="T_f9413">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9413_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f9413_level0_col1" class="col_heading level0 col1" >Accuracy(Train)</th>
#       <th id="T_f9413_level0_col2" class="col_heading level0 col2" >Accuracy(Slow)</th>
#       <th id="T_f9413_level0_col3" class="col_heading level0 col3" >Accuracy(Fast)</th>
#       <th id="T_f9413_level0_col4" class="col_heading level0 col4" >F1(Train)</th>
#       <th id="T_f9413_level0_col5" class="col_heading level0 col5" >F1(Slow)</th>
#       <th id="T_f9413_level0_col6" class="col_heading level0 col6" >F1(Fast)</th>
#       <th id="T_f9413_level0_col7" class="col_heading level0 col7" >Precision(Train)</th>
#       <th id="T_f9413_level0_col8" class="col_heading level0 col8" >Precision(Slow)</th>
#       <th id="T_f9413_level0_col9" class="col_heading level0 col9" >Precision(Fast)</th>
#       <th id="T_f9413_level0_col10" class="col_heading level0 col10" >Recall(Train)</th>
#       <th id="T_f9413_level0_col11" class="col_heading level0 col11" >Recall(Slow)</th>
#       <th id="T_f9413_level0_col12" class="col_heading level0 col12" >Recall(Fast)</th>
#       <th id="T_f9413_level0_col13" class="col_heading level0 col13" >Log_loss(Train)</th>
#       <th id="T_f9413_level0_col14" class="col_heading level0 col14" >Log_loss(Slow)</th>
#       <th id="T_f9413_level0_col15" class="col_heading level0 col15" >Log_loss(Fast)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9413_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_f9413_row0_col0" class="data row0 col0" >QuadraticDiscriminantAnalysis</td>
#       <td id="T_f9413_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_f9413_row0_col2" class="data row0 col2" >0.041667</td>
#       <td id="T_f9413_row0_col3" class="data row0 col3" >0.066667</td>
#       <td id="T_f9413_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_f9413_row0_col5" class="data row0 col5" >0.034811</td>
#       <td id="T_f9413_row0_col6" class="data row0 col6" >0.061280</td>
#       <td id="T_f9413_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_f9413_row0_col8" class="data row0 col8" >0.058937</td>
#       <td id="T_f9413_row0_col9" class="data row0 col9" >0.058178</td>
#       <td id="T_f9413_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_f9413_row0_col11" class="data row0 col11" >0.041667</td>
#       <td id="T_f9413_row0_col12" class="data row0 col12" >0.066667</td>
#       <td id="T_f9413_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_f9413_row0_col14" class="data row0 col14" >34.541834</td>
#       <td id="T_f9413_row0_col15" class="data row0 col15" >33.640743</td>
#     </tr>
#     <tr>
#       <th id="T_f9413_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_f9413_row1_col0" class="data row1 col0" >LogisticRegression</td>
#       <td id="T_f9413_row1_col1" class="data row1 col1" >0.975000</td>
#       <td id="T_f9413_row1_col2" class="data row1 col2" >0.100000</td>
#       <td id="T_f9413_row1_col3" class="data row1 col3" >0.675000</td>
#       <td id="T_f9413_row1_col4" class="data row1 col4" >0.974867</td>
#       <td id="T_f9413_row1_col5" class="data row1 col5" >0.036770</td>
#       <td id="T_f9413_row1_col6" class="data row1 col6" >0.658406</td>
#       <td id="T_f9413_row1_col7" class="data row1 col7" >0.975535</td>
#       <td id="T_f9413_row1_col8" class="data row1 col8" >0.023213</td>
#       <td id="T_f9413_row1_col9" class="data row1 col9" >0.685637</td>
#       <td id="T_f9413_row1_col10" class="data row1 col10" >0.975000</td>
#       <td id="T_f9413_row1_col11" class="data row1 col11" >0.100000</td>
#       <td id="T_f9413_row1_col12" class="data row1 col12" >0.675000</td>
#       <td id="T_f9413_row1_col13" class="data row1 col13" >0.313844</td>
#       <td id="T_f9413_row1_col14" class="data row1 col14" >6.002257</td>
#       <td id="T_f9413_row1_col15" class="data row1 col15" >1.154902</td>
#     </tr>
#     <tr>
#       <th id="T_f9413_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_f9413_row2_col0" class="data row2 col0" >ExtraTreesClassifier</td>
#       <td id="T_f9413_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_f9413_row2_col2" class="data row2 col2" >0.088889</td>
#       <td id="T_f9413_row2_col3" class="data row2 col3" >0.761111</td>
#       <td id="T_f9413_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_f9413_row2_col5" class="data row2 col5" >0.054144</td>
#       <td id="T_f9413_row2_col6" class="data row2 col6" >0.744359</td>
#       <td i

# %%
explainer = shap.TreeExplainer(best_model_fast)
shap_values_fast = explainer.shap_values(fX_test)

# %%
VisualizationUtils.shap_plotter([np.mean(shap_values_fast, axis=2)], 
                          fX_test, title="Feature Importance Using SHAP Values (Medal Of Honor)",
                          class_names=['Medal Of Honor'])

# %%
VisualizationUtils.confusion_matrices(cm_slow, cm_fast)

# %%
evaluator.plot_accuracy_by_vote(best_model_fast, fX_test, fy_test, increment=1)
# Out:
# Vote Over Time Data Table:
#     Seconds in Voting Set  Voting Accuracy
# 0                      10         0.866667
# 1                      20         0.866667
# 2                      30         0.800000
# 3                      40         0.800000
# 4                      50         0.866667
# 5                      60         0.866667
# 6                      70         0.900000
# 7                      80         0.933333
# 8                      90         0.933333
# 9                     100         0.900000
# 10                    110         0.866667
# 11                    120         0.866667

# %%
evaluator.accuracy_over_time(fX, fy,best_model_fast_name, range(1,9), X_test, y_test, fX_test, fy_test)
# Out:
# Accuracy Over Time Data Table:
#    Seconds in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                       60            0.036111            0.280556
# 1                      120            0.052778            0.383333
# 2                      180            0.063889            0.430556
# 3                      240            0.069444            0.486111
# 4                      300            0.063889            0.519444
# 5                      360            0.052778            0.558333
# 6                      420            0.094444            0.619444
# 7                      480            0.066667            0.780556

# %%
evaluator.accuracy_over_ids(fX_train, fy_train,best_model_fast_name, X_test, y_test,fX_test, fy_test)
# Out:
# ID Over Time Data Table:
#    Number of IDs in Training Set  Slow Game Accuracy  Fast Game Accuracy
# 0                              5            0.450000            0.933333
# 1                             10            0.108333            0.866667
# 2                             15            0.066667            0.744444
# 3                             20            0.095833            0.804167
# 4                             25            0.076667            0.756667
# 5                             30            0.066667            0.780556
